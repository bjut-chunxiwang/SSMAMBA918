# %% [markdown]
# # Model Prototyping
#
# Building the basis for our model experimentation

# %%
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"
import numpy as np
import pandas as pd
import torch
import os
import json

from torch.utils import data
from torch.nn import Conv2d, AvgPool2d, ReLU, Dropout, Flatten, Linear, Sequential, Module
from torch.optim import Adam
from time import time

from tqdm import tqdm

device = torch.device("cuda:0")
torch.set_default_dtype(torch.float64)

MODELS_DIR  = '/home/cxw/sonos_rirs/models/'

# %%
model_dict = {}
model_dict['name'] = "testrun2_regularization"
model_dict['notes'] = "same as test run but with regularization"
model_dict['data_path'] = '/home/cxw/sonos_rirs/features/080122_5k_phase/feature_df.csv'
model_dict['model_path'] = os.path.join(MODELS_DIR, model_dict['name'])

# %%
try:
    # 尝试导入IPython
    from IPython import get_ipython
    # 检查是否在IPython环境下
    if get_ipython() is not None:
        # 加载autoreload扩展
        # %load_ext autoreload
        # 设置autoreload为2
        # %autoreload 2
except ImportError:
    # 如果IPython没有被安装，则不作任何操作
    pass

# %%
# %autoreload 2
# import volume_estimation.modeling as model_funcs
# model_funcs.train_model(model_funcs.Baseline_Model, model_dict,\
#                         overwrite=True, epochs=1,log=False) #######################################################

# %%
feat_df = pd.read_csv(model_dict['data_path'])
model_path = os.path.join(MODELS_DIR, model_dict['name'])

dataset = []

    
def create_dataloader(feature_df, batch_size=1, log=True):
    dataset = []
    for row in tqdm(feature_df.iterrows()):
        feat_file = row[1]['file_feature']
        loaded = np.load(feat_file)

        feature = loaded['feat']
        feature = feature.reshape((feature.shape[0], feature.shape[1]))
        feature = np.real(feature)

        vol = loaded['vol']
        if log:
            vol = np.log10(vol)
        dataset.append((feature, vol))
    
    dataloader = torch.utils.data.DataLoader(dataset, batch_size=batch_size)
    return dataloader

dataloader = create_dataloader(feat_df, log=False)
# Out:
# 32000it [00:11, 2713.57it/s]

# %%
savename = './testmodeldict.json'
with open(savename, 'w') as f:
    json.dump(model_dict, f)
    
with open(savename) as f:
    load_dict = json.load(f)
    
for key in load_dict.keys():
    print(key, load_dict[key])
# Out:
# name testrun2_regularization
# notes same as test run but with regularization
# data_path /home/cxw/sonos_rirs/features/080122_5k_phase/feature_df.csv
# model_path /home/cxw/sonos_rirs/models/testrun2_regularization

# %%
train_df = feat_df[feat_df['split']=='train']
val_df = feat_df[feat_df['split']=='val']
test_df = feat_df[feat_df['split']=='test']

print("Creating training dataloader")
train_dataloader = create_dataloader(train_df, batch_size=128)        ##################################batch_size

print("Creating validation dataloader")
val_dataloader = create_dataloader(val_df)

print("Creating test dataloader")
test_dataloader = create_dataloader(test_df)
# Out:
# Creating training dataloader
# 19200it [00:07, 2732.24it/s]
# Creating validation dataloader
# 6420it [00:02, 2837.26it/s]
# Creating test dataloader
# 6380it [00:02, 2792.89it/s]

# %%
features, labels = next(iter(train_dataloader))
# features = features.squeeze(1)
# features = features.transpose(1,2)
print(f"Feature batch shape: {features.size()}")
print(f"Labels batch shape: {labels.size()}")
# Out:
# Feature batch shape: torch.Size([128, 30, 1997])
# Labels batch shape: torch.Size([128])

# %%
# class Baseline_Model(Module):
#     def __init__(self, input_shape):
#         #accepts a tuple with the height/width of the feature
#         #matrix to set the FC layer dimensions
#         super(Baseline_Model, self).__init__()
        
#         #block1
#         Conv1 = Conv2d(1, 30, kernel_size=(1,10), stride=(1,1))
#         Avgpool1 = AvgPool2d((1,2), stride=(1,2))

#         #block2
#         Conv2 = Conv2d(30, 20, kernel_size=(1,10), stride=(1,1))
#         Avgpool2 = AvgPool2d((1,2), stride=(1,2))

#         #block3
#         Conv3 = Conv2d(20, 10, kernel_size=(1,10), stride=(1,1))
#         Avgpool3 = AvgPool2d((1,2), stride=(1,2))

#         #block4
#         Conv4 = Conv2d(10, 10, kernel_size=(1,10), stride=(1,1))
#         Avgpool4 = AvgPool2d((1,2), stride=(1,2))

#         #block5
#         Conv5 = Conv2d(10, 5, kernel_size=(3,9), stride=(1,1))
#         Avgpool5 = AvgPool2d((1,2), stride=(1,2))

#         #block6
#         Conv6 = Conv2d(5, 5, kernel_size=(3,9), stride=(1,1))
#         Avgpool6 = AvgPool2d((2,2), stride=(2,2))

#         #dropout
#         dropout_layer = Dropout(p=0.5)
#         height5 = input_shape[0] - 2
#         height6 = (height5 - 2) // 2

#         time1 = (input_shape[1] - 9) // 2
#         time2 = (time1 - 9) // 2
#         time3 = (time2 - 9) // 2
#         time4 = (time3 - 9) // 2
#         time5 = (time4 - 7) // 2
#         time6 = (time5 - 7) // 2

#         flat_dims = 5 * height6 * time6
#         fc_layer = Linear(flat_dims, 1)
        
#         self.net = Sequential(
#                     Conv1, ReLU(), Avgpool1,
#                     Conv2, ReLU(), Avgpool2,
#                     Conv3, ReLU(), Avgpool3,
#                     Conv4, ReLU(), Avgpool4,
#                     Conv5, ReLU(), Avgpool5,
#                     Conv6, ReLU(), Avgpool6,
#                     dropout_layer, Flatten(),
#                     fc_layer, Flatten()
#                 )
#     def forward(self, x):
#         for layer in self.net:
#             x = layer(x)
#         return x

# %%
"""
Author: Siavash Shams
Date: 4/10/2024

This script contains the implementation of the AMBAModel and ASTModel for audio processing tasks.
The ASTModel is adapted from Yuan Gong's code.

"""
import os
os.environ["HF_ENDPOINT"]='https://hf-mirror.com'
import torch.nn as nn
import torch
import sys

from timm.models.layers import trunc_normal_
import timm
import numpy as np
from timm.models.layers import to_2tuple
from random import randrange
from matplotlib import pyplot as plt
import random

# from src.models.mamba.benchmarks.benchmark_generation_mamba_simple import device
device = "cuda"
sys.path.append('/home/cxw/Vim')
sys.path.append('/home/cxw/Vim/vim')
sys.path.append('/home/cxw/Vim/vim/mamba-1p1p1')



from models_mamba import VisionMamba
from mamba_ssm.ops.triton.layernorm import RMSNorm, layer_norm_fn, rms_norm_fn
    

    
    
class PatchEmbed(nn.Module):
    """ Image to Patch Embedding
    """
    def __init__(self, img_size=224, patch_size=16, in_chans=3, embed_dim=768):
        super().__init__()
        img_size = to_2tuple(img_size)
        patch_size = to_2tuple(patch_size)
        num_patches = (img_size[1] // patch_size[1]) * (img_size[0] // patch_size[0])
        self.img_size = img_size
        self.patch_size = patch_size
        self.num_patches = num_patches

        self.proj = nn.Conv2d(in_chans, embed_dim, kernel_size=patch_size, stride=patch_size)

    def forward(self, x):
        x = self.proj(x).flatten(2).transpose(1, 2)
        return x

def get_sinusoid_encoding(n_position, d_hid):
    ''' Sinusoid position encoding table '''

    def get_position_angle_vec(position):
        return [position / np.power(10000, 2 * (hid_j // 2) / d_hid) for hid_j in range(d_hid)]

    sinusoid_table = np.array([get_position_angle_vec(pos_i) for pos_i in range(n_position)])
    sinusoid_table[:, 0::2] = np.sin(sinusoid_table[:, 0::2])  # dim 2i
    sinusoid_table[:, 1::2] = np.cos(sinusoid_table[:, 1::2])  # dim 2i+1

    return torch.FloatTensor(sinusoid_table).unsqueeze(0)

class AMBAModel(nn.Module):
    def __init__(self, label_dim=527,
                 fshape=128, tshape=2, fstride=128, tstride=2,
                 input_fdim=128, input_tdim=1024, model_size='base',
                 pretrain_stage=True, load_pretrained_mdl_path=None, vision_mamba_config=None):
        
        print("Vision Mamba Config:", vision_mamba_config)
        super(AMBAModel, self).__init__()
        #assert timm.__version__ == '0.4.5', 'Please use timm == 0.4.5, the code might not be compatible with newer versions.'

        # override timm input shape restriction
        timm.models.vision_transformer.PatchEmbed = PatchEmbed

        # pretrain the AMBA models
        if pretrain_stage == True:
            if load_pretrained_mdl_path != None:
                raise ValueError('Setting load_pretrained_mdl_path at pretraining stage is useless, pretraining is always from scratch, please change it to None.')
            if fstride != fshape or tstride != tshape:
                raise ValueError('fstride != fshape or tstride != tshape, they must be same at the pretraining stage, patch split overlapping is not supported.')

            
            default_vision_mamba_config = {
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 24,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }
            
            
            combined_vision_mamba_config = {**default_vision_mamba_config, **vision_mamba_config}
            # Replace self.v with MambaBlocksSequential
            print("combined_vision_mamba_config",combined_vision_mamba_config)
            self.v = VisionMamba(**combined_vision_mamba_config)

            self.cls_token_num = 1
            self.original_num_patches = self.v.patch_embed.num_patches
            self.oringal_hw = int(self.original_num_patches ** 0.5)
            self.original_embedding_dim = self.v.pos_embed.shape[2]

            # SSL Pretraining Code
            self.softmax = nn.Softmax(dim=-1)
            self.lsoftmax = nn.LogSoftmax(dim=-1)
            self.fshape, self.tshape = fshape, tshape
            self.fstride, self.tstride = fstride, tstride
            self.input_fdim, self.input_tdim = input_fdim, input_tdim
            # this is a trick to make state_dict to track pretraining input_fdim and input_tdim and save them by using torch.save
            self.p_input_fdim, self.p_input_tdim = nn.Parameter(torch.tensor(input_fdim), requires_grad=False), nn.Parameter(torch.tensor(input_tdim), requires_grad=False)

            self.cpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            # masked patch reconstruction (generative objective) layer
            self.gpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            self.unfold = torch.nn.Unfold(kernel_size=(fshape, tshape), stride=(fstride, tstride))

            # we use learnable mask embedding (follow the BEIT paper), but using a fixed mask embedding (e.g., 0) leads to same performance.
            self.mask_embed = nn.Parameter(torch.zeros([1, 1, self.original_embedding_dim]))
            self.mask_embed = torch.nn.init.xavier_normal_(self.mask_embed)

            # get the intermediate shape
            self.p_f_dim, self.p_t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            num_patches = self.p_f_dim * self.p_t_dim
            self.num_patches = num_patches
            self.v.patch_embed.num_patches = num_patches
            print('pretraining patch split stride: frequency={:d}, time={:d}'.format(fstride, tstride))
            print('pretraining patch shape: frequency={:d}, time={:d}'.format(fshape, tshape))
            print('pretraining patch array dimension: frequency={:d}, time={:d}'.format(self.p_f_dim, self.p_t_dim))
            print('pretraining number of patches={:d}'.format(num_patches))

            # the linear patch projection layer, use 1 channel for spectrogram rather than the original 3 channels for RGB images.
            new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
            self.v.patch_embed.proj = new_proj

            # use trainable positional embedding
            new_pos_embed = nn.Parameter(torch.zeros(1, self.v.patch_embed.num_patches + self.cls_token_num, self.original_embedding_dim))
            self.v.pos_embed = new_pos_embed
            trunc_normal_(self.v.pos_embed, std=.02)

        # use a pretrained models for finetuning
        elif pretrain_stage == False:
            device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
            if load_pretrained_mdl_path == None:
                raise ValueError('Please set load_pretrained_mdl_path to load a pretrained models.')
            sd = torch.load(load_pretrained_mdl_path, map_location=device)
            # get the fshape and tshape, input_fdim and input_tdim in the pretraining stage
            try:
                p_fshape, p_tshape = sd['module.v.patch_embed.proj.weight'].shape[2], sd['module.v.patch_embed.proj.weight'].shape[3]
                p_input_fdim, p_input_tdim = sd['module.p_input_fdim'].item(), sd['module.p_input_tdim'].item()
            except:
                raise  ValueError('The model loaded is not from a torch.nn.Dataparallel object. Wrap it with torch.nn.Dataparallel and try again.')

            print('now load a SSL pretrained models from ' + load_pretrained_mdl_path)
            # during pretraining, fstride=fshape and tstride=tshape because no patch overlapping is used
            # here, input_fdim and input_tdim should be that used in pretraining, not that in the fine-tuning.
            # we need to know input_fdim and input_tdim to do positional embedding cut/interpolation.
            # generally it should be better to use same input_fdim during pretraining and finetuning, but input_tdim can be safely different
            default_vision_mamba_config = {
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 24,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }
            
            
            combined_vision_mamba_config = {**default_vision_mamba_config, **vision_mamba_config}
            # Replace self.v with MambaBlocksSequential
            print("combined_vision_mamba_config",combined_vision_mamba_config)

            audio_model = AMBAModel(fstride=p_fshape, tstride=p_tshape, fshape=p_fshape, tshape=p_tshape,
                                   input_fdim=p_input_fdim, input_tdim=p_input_tdim, pretrain_stage=True, model_size=model_size, vision_mamba_config=combined_vision_mamba_config)
            
            audio_model = torch.nn.DataParallel(audio_model)
            audio_model.load_state_dict(sd, strict=False)
            device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            self.v = audio_model.module.v
            self.original_embedding_dim = self.v.pos_embed.shape[2]
            self.cls_token_num = audio_model.module.cls_token_num

            # mlp head for fine-tuning
            self.mlp_head = nn.Sequential(nn.LayerNorm(self.original_embedding_dim),
                                          nn.Linear(self.original_embedding_dim, label_dim))

            f_dim, t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            # patch array dimension during pretraining
            p_f_dim, p_t_dim = audio_model.module.p_f_dim, audio_model.module.p_t_dim
            num_patches = f_dim * t_dim
            p_num_patches = p_f_dim * p_t_dim
            self.v.patch_embed.num_patches = num_patches
            print('fine-tuning patch split stride: frequncey={:d}, time={:d}'.format(fstride, tstride))
            print('fine-tuning number of patches={:d}'.format(num_patches))

            # patch shape should be same for pretraining and fine-tuning
            # if fshape != p_fshape or tshape != p_tshape:
            #     raise ValueError('The patch shape of pretraining and fine-tuning is not consistant, pretraining: f={:d}, t={:d}, finetuning: f={:d}, t={:d}'.format(p_fshape, p_tshape, fshape, tshape))

            # patch split stride generally should be different for pretraining and fine-tuning, as patch split overlapping is only used in finetuning
            # during pretraining, p_fshape = p_fstride and p_tshape = p_tstride
            if fstride != p_fshape or tstride != p_tshape:
                # initialize a new patch embedding layer with desired new stride.
                new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
                # but the weights of patch embedding layer is still got from the pretrained models
                new_proj.weight = torch.nn.Parameter(torch.sum(self.v.patch_embed.proj.weight, dim=1).unsqueeze(1))
                new_proj.bias = self.v.patch_embed.proj.bias
                self.v.patch_embed.proj = new_proj

            new_pos_embed = self.v.pos_embed[:, self.cls_token_num:, :].detach().reshape(1, p_num_patches, self.original_embedding_dim).transpose(1, 2).reshape(1, self.original_embedding_dim, p_f_dim, p_t_dim)
            # cut or interpolate the positional embedding
            if t_dim < p_t_dim:
                new_pos_embed = new_pos_embed[:, :, :, int(p_t_dim/2) - int(t_dim / 2): int(p_t_dim/2) - int(t_dim / 2) + t_dim]
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(8, t_dim), mode='bilinear')
            if f_dim < p_f_dim:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')

            new_pos_embed = new_pos_embed.reshape(1, self.original_embedding_dim, num_patches).transpose(1, 2)
            self.v.pos_embed = nn.Parameter(torch.cat([self.v.pos_embed[:, :self.cls_token_num, :].detach(), new_pos_embed], dim=1))

    # get the shape of intermediate representation.
    def get_shape(self, fstride, tstride, input_fdim, input_tdim, fshape, tshape):
        test_input = torch.randn(1, 1, input_fdim, input_tdim)
        test_proj = nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
        test_out = test_proj(test_input)
        f_dim = test_out.shape[2]
        t_dim = test_out.shape[3]
        return f_dim, t_dim

    # generate mask for 16*16 patch
    def gen_maskid_patch(self, sequence_len=512, mask_size=100, cluster=3):
        mask_id = []

        # randomize clutering factor in [3,6)
        cur_clus = randrange(cluster) + 3

        while len(list(set(mask_id))) <= mask_size:
            start_id = randrange(sequence_len)

            # this improves the efficiency, but might change the pretrained model
            # while start_id in mask_id:
            #     start_id = randrange(sequence_len)

            cur_mask = []
            for i in range(0, cur_clus):
                for j in range(0, cur_clus):
                    mask_cand = start_id + self.p_t_dim * i + j
                    if mask_cand > 0 and mask_cand < sequence_len:
                        cur_mask.append(mask_cand)
            mask_id = mask_id + cur_mask
        mask_id = list(set(mask_id))[:mask_size]
        return torch.tensor(mask_id)

    # using cluster for frame masking hurts the performance, so just use the naive random sampling
    def gen_maskid_frame(self, sequence_len=512, mask_size=100):
        mask_id = random.sample(range(0, sequence_len), mask_size)
        return torch.tensor(mask_id)
    
    def finetuningavgtok_1sec(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                hidden_states, residual = layer(hidden_states, residual)
        else:
            for i in range(len(self.v.layers) // 2):
                hidden_states_f, residual_f = self.v.layers[i * 2](hidden_states, residual)
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](hidden_states.flip([1]), None if residual is None else residual.flip([1]))
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        x = self.v.norm_f(hidden_states)

        # Average output of tokens within each 1-second segment
        tokens_per_second = x.shape[1] // 60  
        x_averaged = torch.stack([torch.mean(x[:, i * tokens_per_second:(i + 1) * tokens_per_second, :], dim=1) for i in range(60)], dim=1)
        x_averaged = self.mlp_head(x_averaged)
        return x_averaged

    def finetuningavgtok(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x
        x = self.v.pos_drop(x)
        
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        x = self.v.norm_f(hidden_states)

        # average output of all tokens except cls token(s)
        x = torch.mean(x[:, self.cls_token_num:, :], dim=1)
        x = self.mlp_head(x)
        return x

    def finetuningcls(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

       
        x = self.v.norm_f(hidden_states)


        # if models has two cls tokens (DEIT), average as the clip-level representation
        if self.cls_token_num == 2:
            x = (x[:, 0] + x[:, 1]) / 2
        else:
            x = x[:, 0]
        x = self.mlp_head(x)
        return x

    # masked patch pretraining with discriminative objective
    def mpc(self, x, mask_patch, cluster, show_mask=False):
        input = self.unfold(x).transpose(1, 2)
        B = x.shape[0]
        # x in shape (batch_size, sequence_len, embedding dim)
        x = self.v.patch_embed(x)

        # encode the patch
        # size 12(batch_size) * 100(#mask_patch) * 768(hidden_dim), prepare to save the true values of masked samples
        encode_samples = torch.empty((B, mask_patch, 256), device=x.device, requires_grad=False).float()
        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)

        # for each audio clip in the batch
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            # copy the masked embeddings, note gradients are stopped in this path
            encode_samples[i] = input[i, mask_index[i], :].clone().detach()
            # mask the encode samples with 0
            mask_dense[i, mask_index[i], :] = 0

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # mask the patch
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # pass through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        #dist_token = self.v.dist_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
    
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        # return only cls token if it exists
        
        x = self.v.norm_f(hidden_states)
        
        
   
        pred = torch.empty((B, mask_patch, 256), device='cpu').float()  # e.g. size 12*100*768
        for i in range(B):
            #  +2 for indexes because skipping the cls and dis token
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            pred[i] = self.cpredlayer(x[i, mask_index[i] + self.cls_token_num, :])

        # calculate the NCE loss
        nce = torch.tensor(0.0).to(x.device)
        correct = torch.tensor(0.0).to(x.device)
        for i in np.arange(0, B):
            # negative samples are from the same batch
            # 8/12/2022: has a difference with equation (1) in the ssast paper but (likely) performance-wise similar, see https://github.com/YuanGongND/ssast/issues/13
            total = torch.mm(encode_samples[i], torch.transpose(pred[i], 0, 1))  # e.g. size 100*100
            correct += torch.sum(torch.eq(torch.argmax(self.softmax(total), dim=0), torch.arange(0, mask_patch, device=x.device)))  # correct is a tensor
            nce += torch.sum(torch.diag(self.lsoftmax(total)))  # nce is a tensor
        acc = 1. * correct / (B * mask_patch)
        nce = nce / (-1. * B * mask_patch)

        # visualize the masked area, for probing test only, set show_mask = False for any training/inference.
        if show_mask == False:
            return acc, nce
        else:
            if B > 1:
                raise Exception('Currently only support single spectrogram probing test.')

            self.mask_correct = torch.nn.Parameter(torch.arange(0, mask_patch), requires_grad=False)

            pred = input.clone()  # [B, 512, 256]
            masked = input.clone()

            for i in range(B):
                result = [float(t) * 99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)]
                pred[i, mask_index[i], :] = torch.tensor(result).reshape(mask_patch, 1).expand(mask_patch, 256)
                masked[i, mask_index[i], :] = 99.0

            # print(total)
            # print(self.softmax(total))
            # print(torch.argmax(self.softmax(total), dim=0))
            # print(self.mask_correct)
            # print(torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct))
            # print([float(t)*99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)])

            fold = torch.nn.Fold(output_size=([self.input_fdim, self.input_tdim]), kernel_size=(self.fshape, self.tshape), stride=(self.fstride, self.tstride))
            pred = fold(pred.transpose(1, 2))
            masked = fold(masked.transpose(1, 2))

            return pred, masked

        
    # # masked patch pretraining with generative objective
    def mpg(self, input, mask_patch, cluster):
        
        B = input.shape[0]
        x = self.v.patch_embed(input)
        input = self.unfold(input).transpose(1, 2)

        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            mask_dense[i, mask_index[i], :] = 0

        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # go through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        #dist_token = self.v.dist_token.expand(B, -1, -1)
        x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        # mamba impl
        residual = None
        hidden_states = x
        token_position = 0
        if not self.v.if_bidirectional:
            for layer in self.v.layers:
                
                hidden_states, residual = layer(
                    hidden_states, residual
                )
        else:
            # get two layers in a single for-loop
            for i in range(len(self.v.layers) // 2):

                hidden_states_f, residual_f = self.v.layers[i * 2](
                    hidden_states, residual
                )
                hidden_states_b, residual_b = self.v.layers[i * 2 + 1](
                    hidden_states.flip([1]), None if residual == None else residual.flip([1])
                )
                hidden_states = hidden_states_f + hidden_states_b.flip([1])
                residual = residual_f + residual_b.flip([1])

        if not self.v.fused_add_norm:
            if residual is None:
                residual = hidden_states
            else:
                residual = residual + self.v.drop_path(hidden_states)
            hidden_states = self.v.norm_f(residual.to(dtype=self.v.norm_f.weight.dtype))
        else:
            # Set prenorm=False here since we don't need the residual
            fused_add_norm_fn = rms_norm_fn if isinstance(self.v.norm_f, RMSNorm) else layer_norm_fn
            hidden_states = fused_add_norm_fn(
                self.v.drop_path(hidden_states),
                self.v.norm_f.weight,
                self.v.norm_f.bias,
                eps=self.v.norm_f.eps,
                residual=residual,
                prenorm=False,
                residual_in_fp32=self.v.residual_in_fp32,
            )

        
        x = self.v.norm_f(hidden_states)
        
        pred = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float()  # e.g. size 12*100*256
        target = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float() # e.g. size 12*100*256

        for i in range(B):
            #  +2 for indexes because cls and dis token
            pred[i] = self.gpredlayer(x[i, mask_index[i] + self.cls_token_num, :])
            target[i] = input[i, mask_index[i], :]

        # calculate the MSE loss
        mse = torch.mean((pred - target) ** 2)

        return mse
        
     
    def forward(self, x, task, cluster=True, mask_patch=400):
        # expect input x = (batch_size, time_frame_num, frequency_bins), e.g., (12, 1024, 128)
        x = x.unsqueeze(1)
        x = x.transpose(2, 3)
        # finetuning (ft), use the mean of all token (patch) output as clip-level representation.
        # this is default for SSAMBA fine-tuning as during pretraining, supervision signal is given to each token, not the [cls] token
        if task == 'ft_avgtok':
            return self.finetuningavgtok(x)
        elif task == 'ft_avgtok_1sec':
            return self.finetuningavgtok_1sec(x)
        # alternatively, use the [cls] token output as clip-level representation.
        elif task == 'ft_cls':
            return self.finetuningcls(x)
        # pretraining, masked patch classification (discriminative objective)
        elif task == 'pretrain_mpc':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster)
        # pretraining, masked patch reconstruction (generative objective)
        elif task == 'pretrain_mpg':
            return self.mpg(x, mask_patch=mask_patch, cluster=cluster)
        elif task == 'visualize_mask':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster, show_mask=True)
        else:
            raise Exception('Task unrecognized.')

            
class ASTModel(nn.Module):
    def __init__(self, label_dim=527,
                 fshape=128, tshape=2, fstride=128, tstride=2,
                 input_fdim=128, input_tdim=1024, model_size='base_nokd',
                 pretrain_stage=True, load_pretrained_mdl_path=None):

        super(ASTModel, self).__init__()
        assert timm.__version__ == '0.4.5', 'Please use timm == 0.4.5, the code might not be compatible with newer versions.'

        # override timm input shape restriction
        timm.models.vision_transformer.PatchEmbed = PatchEmbed

        # pretrain the AST models
        if pretrain_stage == True:
            if load_pretrained_mdl_path != None:
                raise ValueError('Setting load_pretrained_mdl_path at pretraining stage is useless, pretraining is always from scratch, please change it to None.')
            if fstride != fshape or tstride != tshape:
                raise ValueError('fstride != fshape or tstride != tshape, they must be same at the pretraining stage, patch split overlapping is not supported.')

            # if AudioSet pretraining is not used (but ImageNet pretraining may still apply)
            if model_size == 'tiny':
                self.v = timm.create_model('vit_deit_tiny_distilled_patch16_224', pretrained=False)
                self.heads, self.depth = 3, 12
                self.cls_token_num = 2
            elif model_size == 'small':
                self.v = timm.create_model('vit_deit_small_distilled_patch16_224', pretrained=False)
                self.heads, self.depth = 6, 12
                self.cls_token_num = 2
            elif model_size == 'base':
                self.v = timm.create_model('vit_deit_base_distilled_patch16_384', pretrained=False)
                self.heads, self.depth = 12, 12
                self.cls_token_num = 2
            elif model_size == 'base_nokd':
                self.v = timm.create_model('vit_deit_base_patch16_384', pretrained=False)
                self.heads, self.depth = 12, 12
                self.cls_token_num = 1
            else:
                raise Exception('Model size must be one of tiny, small, base, base_nokd')

            self.original_num_patches = self.v.patch_embed.num_patches
            self.oringal_hw = int(self.original_num_patches ** 0.5)
            self.original_embedding_dim = self.v.pos_embed.shape[2]

            # SSL Pretraining Code
            self.softmax = nn.Softmax(dim=-1)
            self.lsoftmax = nn.LogSoftmax(dim=-1)
            self.fshape, self.tshape = fshape, tshape
            self.fstride, self.tstride = fstride, tstride
            self.input_fdim, self.input_tdim = input_fdim, input_tdim
            # this is a trick to make state_dict to track pretraining input_fdim and input_tdim and save them by using torch.save
            self.p_input_fdim, self.p_input_tdim = nn.Parameter(torch.tensor(input_fdim), requires_grad=False), nn.Parameter(torch.tensor(input_tdim), requires_grad=False)

            # masked patch classification (discriminative objective) layer
            # we use two layers for pretext task, but using a single layer has similar performance.
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            self.cpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            # masked patch reconstruction (generative objective) layer
            self.gpredlayer = nn.Sequential(nn.Linear(self.original_embedding_dim, self.original_embedding_dim), nn.ReLU(), nn.Linear(self.original_embedding_dim, 256))
            self.unfold = torch.nn.Unfold(kernel_size=(fshape, tshape), stride=(fstride, tstride))

            # we use learnable mask embedding (follow the BEIT paper), but using a fixed mask embedding (e.g., 0) leads to same performance.
            self.mask_embed = nn.Parameter(torch.zeros([1, 1, self.original_embedding_dim]))
            self.mask_embed = torch.nn.init.xavier_normal_(self.mask_embed)

            # get the intermediate shape
            self.p_f_dim, self.p_t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            num_patches = self.p_f_dim * self.p_t_dim
            self.num_patches = num_patches
            self.v.patch_embed.num_patches = num_patches
            print('pretraining patch split stride: frequency={:d}, time={:d}'.format(fstride, tstride))
            print('pretraining patch shape: frequency={:d}, time={:d}'.format(fshape, tshape))
            print('pretraining patch array dimension: frequency={:d}, time={:d}'.format(self.p_f_dim, self.p_t_dim))
            print('pretraining number of patches={:d}'.format(num_patches))

            # the linear patch projection layer, use 1 channel for spectrogram rather than the original 3 channels for RGB images.
            new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
            self.v.patch_embed.proj = new_proj

            # use trainable positional embedding
            new_pos_embed = nn.Parameter(torch.zeros(1, self.v.patch_embed.num_patches + self.cls_token_num, self.original_embedding_dim))
            self.v.pos_embed = new_pos_embed
            trunc_normal_(self.v.pos_embed, std=.02)

        # use a pretrained models for finetuning
        elif pretrain_stage == False:
            device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
            if load_pretrained_mdl_path == None:
                raise ValueError('Please set load_pretrained_mdl_path to load a pretrained models.')
            sd = torch.load(load_pretrained_mdl_path, map_location=device)
            # get the fshape and tshape, input_fdim and input_tdim in the pretraining stage
            try:
                p_fshape, p_tshape = sd['module.v.patch_embed.proj.weight'].shape[2], sd['module.v.patch_embed.proj.weight'].shape[3]
                p_input_fdim, p_input_tdim = sd['module.p_input_fdim'].item(), sd['module.p_input_tdim'].item()
            except:
                raise  ValueError('The model loaded is not from a torch.nn.Dataparallel object. Wrap it with torch.nn.Dataparallel and try again.')

            print('now load a SSL pretrained models from ' + load_pretrained_mdl_path)
            # during pretraining, fstride=fshape and tstride=tshape because no patch overlapping is used
            # here, input_fdim and input_tdim should be that used in pretraining, not that in the fine-tuning.
            # we need to know input_fdim and input_tdim to do positional embedding cut/interpolation.
            # generally it should be better to use same input_fdim during pretraining and finetuning, but input_tdim can be safely different
            audio_model = ASTModel(fstride=p_fshape, tstride=p_tshape, fshape=p_fshape, tshape=p_tshape,
                                   input_fdim=p_input_fdim, input_tdim=p_input_tdim, pretrain_stage=True, model_size=model_size)
            audio_model = torch.nn.DataParallel(audio_model)
            audio_model.load_state_dict(sd, strict=False)

            self.v = audio_model.module.v
            self.original_embedding_dim = self.v.pos_embed.shape[2]
            self.cls_token_num = audio_model.module.cls_token_num

            # mlp head for fine-tuning
            self.mlp_head = nn.Sequential(nn.LayerNorm(self.original_embedding_dim),
                                          nn.Linear(self.original_embedding_dim, label_dim))

            f_dim, t_dim = self.get_shape(fstride, tstride, input_fdim, input_tdim, fshape, tshape)
            # patch array dimension during pretraining
            p_f_dim, p_t_dim = audio_model.module.p_f_dim, audio_model.module.p_t_dim
            num_patches = f_dim * t_dim
            p_num_patches = p_f_dim * p_t_dim
            self.v.patch_embed.num_patches = num_patches
            print('fine-tuning patch split stride: frequncey={:d}, time={:d}'.format(fstride, tstride))
            print('fine-tuning number of patches={:d}'.format(num_patches))

            # patch shape should be same for pretraining and fine-tuning
            if fshape != p_fshape or tshape != p_tshape:
                raise ValueError('The patch shape of pretraining and fine-tuning is not consistant, pretraining: f={:d}, t={:d}, finetuning: f={:d}, t={:d}'.format(p_fshape, p_tshape, fshape, tshape))

            # patch split stride generally should be different for pretraining and fine-tuning, as patch split overlapping is only used in finetuning
            # during pretraining, p_fshape = p_fstride and p_tshape = p_tstride
            if fstride != p_fshape or tstride != p_tshape:
                # initialize a new patch embedding layer with desired new stride.
                new_proj = torch.nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
                # but the weights of patch embedding layer is still got from the pretrained models
                new_proj.weight = torch.nn.Parameter(torch.sum(self.v.patch_embed.proj.weight, dim=1).unsqueeze(1))
                new_proj.bias = self.v.patch_embed.proj.bias
                self.v.patch_embed.proj = new_proj

            new_pos_embed = self.v.pos_embed[:, self.cls_token_num:, :].detach().reshape(1, p_num_patches, self.original_embedding_dim).transpose(1, 2).reshape(1, self.original_embedding_dim, p_f_dim, p_t_dim)
            # cut or interpolate the positional embedding
            if t_dim < p_t_dim:
                new_pos_embed = new_pos_embed[:, :, :, int(p_t_dim/2) - int(t_dim / 2): int(p_t_dim/2) - int(t_dim / 2) + t_dim]
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(8, t_dim), mode='bilinear')
            if f_dim < p_f_dim:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')
            else:
                new_pos_embed = torch.nn.functional.interpolate(new_pos_embed, size=(f_dim, t_dim), mode='bilinear')

            new_pos_embed = new_pos_embed.reshape(1, self.original_embedding_dim, num_patches).transpose(1, 2)
            self.v.pos_embed = nn.Parameter(torch.cat([self.v.pos_embed[:, :self.cls_token_num, :].detach(), new_pos_embed], dim=1))

    # get the shape of intermediate representation.
    def get_shape(self, fstride, tstride, input_fdim, input_tdim, fshape, tshape):
        test_input = torch.randn(1, 1, input_fdim, input_tdim)
        test_proj = nn.Conv2d(1, self.original_embedding_dim, kernel_size=(fshape, tshape), stride=(fstride, tstride))
        test_out = test_proj(test_input)
        f_dim = test_out.shape[2]
        t_dim = test_out.shape[3]
        return f_dim, t_dim

    # generate mask for 16*16 patch
    def gen_maskid_patch(self, sequence_len=512, mask_size=100, cluster=3):
        mask_id = []

        # randomize clutering factor in [3,6)
        cur_clus = randrange(cluster) + 3

        while len(list(set(mask_id))) <= mask_size:
            start_id = randrange(sequence_len)

            # this improves the efficiency, but might change the pretrained model
            # while start_id in mask_id:
            #     start_id = randrange(sequence_len)

            cur_mask = []
            for i in range(0, cur_clus):
                for j in range(0, cur_clus):
                    mask_cand = start_id + self.p_t_dim * i + j
                    if mask_cand > 0 and mask_cand < sequence_len:
                        cur_mask.append(mask_cand)
            mask_id = mask_id + cur_mask
        mask_id = list(set(mask_id))[:mask_size]
        return torch.tensor(mask_id)

    # using cluster for frame masking hurts the performance, so just use the naive random sampling
    def gen_maskid_frame(self, sequence_len=512, mask_size=100):
        mask_id = random.sample(range(0, sequence_len), mask_size)
        return torch.tensor(mask_id)
    
    def finetuningavgtok_1sec(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        
        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # Average output of tokens within each 1-second segment
        tokens_per_second = x.shape[1] // 60  
        x_averaged = torch.stack([torch.mean(x[:, i * tokens_per_second:(i + 1) * tokens_per_second, :], dim=1) for i in range(60)], dim=1)
        x_averaged = self.mlp_head(x_averaged)
        return x_averaged
        

    def finetuningavgtok(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)

        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # average output of all tokens except cls token(s)
        x = torch.mean(x[:, self.cls_token_num:, :], dim=1)
        x = self.mlp_head(x)
        return x

    def finetuningcls(self, x):
        B = x.shape[0]
        x = self.v.patch_embed(x)
        if self.cls_token_num == 2:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            cls_tokens = self.v.cls_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)

        for blk_id, blk in enumerate(self.v.blocks):
            x = blk(x)
        x = self.v.norm(x)

        # if models has two cls tokens (DEIT), average as the clip-level representation
        if self.cls_token_num == 2:
            x = (x[:, 0] + x[:, 1]) / 2
        else:
            x = x[:, 0]
        x = self.mlp_head(x)
        return x

    # masked patch pretraining with discriminative objective
    def mpc(self, x, mask_patch, cluster, show_mask=False):
        input = self.unfold(x).transpose(1, 2)
        B = x.shape[0]
        # x in shape (batch_size, sequence_len, embedding dim)
        x = self.v.patch_embed(x)

        # encode the patch
        # size 12(batch_size) * 100(#mask_patch) * 768(hidden_dim), prepare to save the true values of masked samples
        encode_samples = torch.empty((B, mask_patch, 256), device=x.device, requires_grad=False).float()
        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)

        # for each audio clip in the batch
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            # copy the masked embeddings, note gradients are stopped in this path
            encode_samples[i] = input[i, mask_index[i], :].clone().detach()
            # mask the encode samples with 0
            mask_dense[i, mask_index[i], :] = 0

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # mask the patch
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # pass through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        if self.cls_token_num == 2: 
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        #print("x before blk.shape",x.shape)
        for blk in self.v.blocks:
            x = blk(x)
            #print("blk(x).shape",x.shape)
        x = self.v.norm(x)

        # prediction of the masked patch
        pred = torch.empty((B, mask_patch, 256), device=x.device).float()  # e.g. size 12*100*768
        for i in range(B):
            #  +2 for indexes because skipping the cls and dis token
            # we map the output of transformer (768-dim for base models) to 256-dim patch input space, and then dot product with flattened patch input (also 256-dim) to calculate loss.
            # alternatively, you can map the output of transformer to 768-dim patch embedding space, and dot product with patch embedding. Performance-wise they are similar, but map to 256 space is more efficient.
            pred[i] = self.cpredlayer(x[i, mask_index[i] + self.cls_token_num, :])

        # calculate the NCE loss
        nce = torch.tensor(0.0).to(x.device)
        correct = torch.tensor(0.0).to(x.device)
        for i in np.arange(0, B):
            # negative samples are from the same batch
            # 8/12/2022: has a difference with equation (1) in the ssast paper but (likely) performance-wise similar, see https://github.com/YuanGongND/ssast/issues/13
            total = torch.mm(encode_samples[i], torch.transpose(pred[i], 0, 1))  # e.g. size 100*100
            correct += torch.sum(torch.eq(torch.argmax(self.softmax(total), dim=0), torch.arange(0, mask_patch, device=x.device)))  # correct is a tensor
            nce += torch.sum(torch.diag(self.lsoftmax(total)))  # nce is a tensor
        acc = 1. * correct / (B * mask_patch)
        nce = nce / (-1. * B * mask_patch)

        # visualize the masked area, for probing test only, set show_mask = False for any training/inference.
        if show_mask == False:
            return acc, nce
        else:
            if B > 1:
                raise Exception('Currently only support single spectrogram probing test.')

            self.mask_correct = torch.nn.Parameter(torch.arange(0, mask_patch), requires_grad=False)

            pred = input.clone()  # [B, 512, 256]
            masked = input.clone()

            for i in range(B):
                result = [float(t) * 99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)]
                pred[i, mask_index[i], :] = torch.tensor(result).reshape(mask_patch, 1).expand(mask_patch, 256)
                masked[i, mask_index[i], :] = 99.0

            # print(total)
            # print(self.softmax(total))
            # print(torch.argmax(self.softmax(total), dim=0))
            # print(self.mask_correct)
            # print(torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct))
            # print([float(t)*99 for t in torch.eq(torch.argmax(self.softmax(total), dim=0), self.mask_correct)])

            fold = torch.nn.Fold(output_size=([self.input_fdim, self.input_tdim]), kernel_size=(self.fshape, self.tshape), stride=(self.fstride, self.tstride))
            pred = fold(pred.transpose(1, 2))
            masked = fold(masked.transpose(1, 2))

            return pred, masked

    # # masked patch pretraining with generative objective
    def mpg(self, input, mask_patch, cluster):
        B = input.shape[0]
        x = self.v.patch_embed(input)
        input = self.unfold(input).transpose(1, 2)

        # size 12(batch_size) * 100(#mask_patch), index of masked patches
        mask_index = torch.empty((B, mask_patch), device=x.device, requires_grad=False).long()
        # size 12(batch_size) * 512(sequence_len) * 768(hidden_dim)
        mask_dense = torch.ones([x.shape[0], x.shape[1], x.shape[2]], device=x.device)
        for i in range(B):
            # randomly generate #mask_patch mask indexes without duplicate
            if cluster == True:
                # use this if you are masking e.g. 16*16 patches
                mask_index[i] = self.gen_maskid_patch(self.num_patches, mask_patch)
            else:
                # use this if you are masking frame, i.e., 128*2 patches
                mask_index[i] = self.gen_maskid_frame(self.num_patches, mask_patch)
            mask_dense[i, mask_index[i], :] = 0

        mask_tokens = self.mask_embed.expand(B, x.shape[1], -1)

        # follow BEIT paper, mask with learnable masking embedding, but no performance diff observed compared with masking with 0s.
        x = x * mask_dense + (1-mask_dense) * mask_tokens

        # go through the Transformer layers
        cls_tokens = self.v.cls_token.expand(B, -1, -1)  # stole cls_tokens impl from Phil Wang, thanks
        if self.cls_token_num == 2: 
            dist_token = self.v.dist_token.expand(B, -1, -1)
            x = torch.cat((cls_tokens, dist_token, x), dim=1)
        else:
            x = torch.cat((cls_tokens, x), dim=1)
        x = x + self.v.pos_embed
        x = self.v.pos_drop(x)
        for blk in self.v.blocks:
            x = blk(x)
        x = self.v.norm(x)

        pred = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float()  # e.g. size 12*100*256
        target = torch.empty((B, mask_patch, self.fshape * self.tshape), device=x.device).float() # e.g. size 12*100*256

        for i in range(B):
            #  +2 for indexes because cls and dis token
            pred[i] = self.gpredlayer(x[i, mask_index[i] + self.cls_token_num, :])
            target[i] = input[i, mask_index[i], :]

        # calculate the MSE loss
        mse = torch.mean((pred - target) ** 2)

        return mse

    def forward(self, x, task, cluster=True, mask_patch=400):
        # expect input x = (batch_size, time_frame_num, frequency_bins), e.g., (12, 1024, 128)
        x = x.unsqueeze(1)
        x = x.transpose(2, 3)

        # finetuning (ft), use the mean of all token (patch) output as clip-level representation.
        # this is default for SSAST fine-tuning as during pretraining, supervision signal is given to each token, not the [cls] token
        if task == 'ft_avgtok':
            return self.finetuningavgtok(x)
        elif task == 'ft_avgtok_1sec':
            return self.finetuningavgtok_1sec(x)
        # alternatively, use the [cls] token output as clip-level representation.
        elif task == 'ft_cls':
            return self.finetuningcls(x)
        # pretraining, masked patch classification (discriminative objective)
        elif task == 'pretrain_mpc':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster)
        # pretraining, masked patch reconstruction (generative objective)
        elif task == 'pretrain_mpg':
            return self.mpg(x, mask_patch=mask_patch, cluster=cluster)
        elif task == 'visualize_mask':
            return self.mpc(x, mask_patch=mask_patch, cluster=cluster, show_mask=True)
        else:
            raise Exception('Task unrecognized.')


if __name__ == '__main__':
    # fine-tuning stage
    # now you have a labeled dataset you want to finetune AST on
    # suppose the avg length is 100 frames (1s) and there are 35 classes
    # the fshape and tshape must be same in pretraining and finetuning
    # but fstride and tstride can be different in pretraining and finetuning
    # using smaller strides improves the performance but also increase the computational overhead
    # set pretrain_stage as False since now is in the finetuning stage
    # provide the path of the pretrained model you want to load
    input_tdim = 1997  # fine-tuning data length can be different with pretraining data length
    ast_mdl = AMBAModel(label_dim=1,
                 fshape=16, tshape=16, fstride=10, tstride=10,
                 input_fdim=30, input_tdim=1997, model_size='base',
                 pretrain_stage=False, load_pretrained_mdl_path='./ssamba_base_400.pth', vision_mamba_config={
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 48,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': True,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': False,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        })
    # # alternatively, use a frame based AST model
    # ast_mdl = ASTModel(label_dim=35,
    #              fshape=128, tshape=2, fstride=128, tstride=1,
    #              input_fdim=128, input_tdim=input_tdim, model_size='base',
    #              pretrain_stage=False, load_pretrained_mdl_path='./test_mdl.pth')

    # do finetuning, see src/traintest.py for our finetuning code
    test_input = torch.zeros([128, 1997, 30]).to(device)
    ast_mdl = ast_mdl.to(device)
    ast_mdl = ast_mdl.cuda()
    # print('test_input.shape',test_input.shape)
    prediction = ast_mdl(test_input, task='ft_avgtok')
    # output should in shape [batch_size, label_dim]
    print(prediction.shape)
    # calculate the loss, do back propagate, etc

    # # (optional) do some probe test
    # test_input = torch.zeros([1, input_tdim, 128]).to(device)
    # acc, nce = ast_mdl(test_input, task='pretrain_mpc', mask_patch=100)
    # # you can visualize the mask
    # pred, masked = ast_mdl(test_input, task='visualize_mask', mask_patch=100)
    # plt.imshow(masked[0,0])
    # plt.show()
# Out:
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# now load a SSL pretrained models from ./ssamba_base_400.pth
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 48, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': True, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': False, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# pretraining patch split stride: frequency=16, time=16
# pretraining patch shape: frequency=16, time=16
# pretraining patch array dimension: frequency=8, time=64
# pretraining number of patches=512
# fine-tuning patch split stride: frequncey=10, time=10
# fine-tuning number of patches=398
# torch.Size([128, 1])

# %%
input_height = features.size()[1]
input_width = features.size()[2]
model = AMBAModel(label_dim=1,
                 fshape=16, tshape=16, fstride=10, tstride=10,
                 input_fdim=30, input_tdim=1997, model_size='base',
                 pretrain_stage=False, load_pretrained_mdl_path='./ssamba_base_400.pth', vision_mamba_config={
            'img_size': (128, 1024),
            'patch_size': 16,
            'stride': 8,
            'embed_dim': 768,
            'depth': 36,
            'rms_norm': True,
            'residual_in_fp32': True,
            'fused_add_norm': False,
            'final_pool_type': 'mean',
            'if_abs_pos_embed': True,
            'if_rope': False,
            'if_rope_residual': True,
            'bimamba_type': "v2",
            'if_cls_token': True,
            'if_devide_out': True,
            'use_middle_cls_token': True,
        }).to(device)
# model = Baseline_Model((input_height, input_width)).to(device)
# Out:
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# now load a SSL pretrained models from ./ssamba_base_400.pth
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# Vision Mamba Config: {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# combined_vision_mamba_config {'img_size': (128, 1024), 'patch_size': 16, 'stride': 8, 'embed_dim': 768, 'depth': 36, 'rms_norm': True, 'residual_in_fp32': True, 'fused_add_norm': False, 'final_pool_type': 'mean', 'if_abs_pos_embed': True, 'if_rope': False, 'if_rope_residual': True, 'bimamba_type': 'v2', 'if_cls_token': True, 'if_devide_out': True, 'use_middle_cls_token': True}
# pretraining patch split stride: frequency=16, time=16
# pretraining patch shape: frequency=16, time=16
# pretraining patch array dimension: frequency=8, time=64
# pretraining number of patches=512
# fine-tuning patch split stride: frequncey=10, time=10
# fine-tuning number of patches=398

# %%
def MSE(output, target):
    loss = torch.mean((output - target)**2)
    return loss

def Bias(output, target):
    loss = torch.mean(output - target)
    return loss

def CovStep(output, target, output_mean, target_mean):
    loss = torch.mean(((output - output_mean) * (target - target_mean)))
    return loss

def MeanAbsLogStep(output, target, log=True):
    #convert out of log
    if log:
        vol_pred = 10**output
        vol_target = 10**target
    else:
        vol_pred = output
        vol_target = target
    loss = torch.mean(torch.abs(torch.log(vol_pred/vol_target)))
    return loss

def compute_eval_metrics(dataloader, model, log=True):
    target_sum = 0
    pred_sum = 0
    n_steps = 0
    
    for (x,y) in dataloader:        
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        target_sum += y.sum()
        pred_sum += pred.sum()
        n_steps += 1
    
    target_mean = target_sum/n_steps
    pred_mean = pred_sum/n_steps
    
    mse = 0
    mean_error = 0
    cov = 0
    abs_log_ratio = 0
    
    var_pred = 0 #technically var * N but gets cancelled out in Pearson calculation
    var_target = 0 
    
    for (x,y) in dataloader:        
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        mse += MSE(pred, y)
        mean_error += Bias(pred, y)
        cov += CovStep(pred, y, pred_mean, target_mean)
        abs_log_ratio += MeanAbsLogStep(pred, y, log=log)
        
        var_pred += MSE(pred, pred_mean)
        var_target += MSE(y, target_mean)
        
        pears = CovStep(pred, y, pred_mean, target_mean)/(torch.sqrt(MSE(pred, pred_mean))*torch.sqrt(MSE(y, target_mean)))
    
    out_dict = {}
    out_dict['mse'] = (mse / n_steps).item()
    out_dict['bias'] = (mean_error / n_steps).item()
    out_dict['pearson_cor'] = (cov/(torch.sqrt(var_pred) * torch.sqrt(var_target))).item()
    out_dict['mean_mult'] = (torch.exp(abs_log_ratio/n_steps)).item()
    
    return out_dict
    
# eval_dict = compute_eval_metrics(val_dataloader, model)
# print(eval_dict)

# %%
import os
import torch
from torch.optim import Adam
from torch.optim.lr_scheduler import StepLR
from time import time

def save_checkpoint(epoch, model, opt, filename='checkpoint.pth.tar'):
    state = {
        'epoch': epoch,
        'model_state_dict': model.state_dict(),
        'optimizer_state_dict': opt.state_dict()
    }
    torch.save(state, filename)

def load_checkpoint(filename='checkpoint.pth.tar'):
    checkpoint = torch.load(filename)
    return checkpoint['epoch'], checkpoint['model_state_dict'], checkpoint['optimizer_state_dict']

# 设置保存模型的文件夹和文件名
save_dir = 'model_checkpoints'
if not os.path.exists(save_dir):
    os.makedirs(save_dir)
checkpoint_path = os.path.join(save_dir, 'checkpoint.pth.tar')
torch.set_default_dtype(torch.float32)
opt = Adam(model.parameters(),lr=0.0001, weight_decay=1e-5)

# 初始化学习率调度器
scheduler = StepLR(opt, step_size=50, gamma=0.5)

start_epoch = 0
if os.path.isfile(checkpoint_path):
    print(f"Loading checkpoint from '{checkpoint_path}'")
    start_epoch, model_state_dict, optimizer_state_dict = load_checkpoint(checkpoint_path)
    model.load_state_dict(model_state_dict)
    opt.load_state_dict(optimizer_state_dict)
    print(f"Resuming from epoch {start_epoch}")

hist = {
	"train_loss": [],
	"val_loss": [],
    "val_bias": [],
    "val_pearson_cor": [],
    "val_mean_mult": []
}

for ep in range(1200000):     #########################################################################                   
    t_start = time()
    model.train()
    
    train_loss = 0
    val_loss = 0
    train_steps = 0
    val_steps = 0
    
    for (x, y) in train_dataloader:
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        loss = MSE(pred, y.reshape((y.shape[0], 1))).to(device)
        
        opt.zero_grad()
        loss.backward()
        opt.step()
        
        train_loss += loss
        train_steps += 1
    
    with torch.no_grad():
        model.eval()
        
        val_metrics = compute_eval_metrics(val_dataloader, model)
    
    
    hist['train_loss'].append(train_loss/train_steps)
    hist['val_loss'].append(val_metrics['mse'])
    hist['val_bias'].append(val_metrics['bias'])
    hist['val_pearson_cor'].append(val_metrics['pearson_cor'])
    hist['val_mean_mult'].append(val_metrics['mean_mult'])
    
    t_end = time()
    
    t_elapsed = t_end - t_start
    print("Epoch: {}\tDuration: {:.2f}s\tTrain loss: {:.4f}\tVal loss: {:.4f}\tVal bias:{:.4f}\tVal Pearson correlation: {:.4e}\tVal MeanMult: {:.4f}"\
          .format(ep, t_elapsed, train_loss/train_steps, val_metrics['mse'],\
                  val_metrics['bias'], val_metrics['pearson_cor'],val_metrics['mean_mult']))

# 更新学习率调度器
    scheduler.step()
    current_lr = opt.param_groups[0]['lr']
    print(f"Current learning rate: {current_lr}")
    
    if (ep + 1) % 20 == 0:
        save_checkpoint(ep + 1, model, opt, checkpoint_path)
        print(f"Checkpoint saved at epoch {ep + 1}")
# Out:
# Loading checkpoint from 'model_checkpoints/checkpoint.pth.tar'
# Resuming from epoch 1420
# Epoch: 0	Duration: 71.63s	Train loss: 0.2916	Val loss: 0.3843	Val bias:-0.0659	Val Pearson correlation: 7.1802e-01	Val MeanMult: 3.0178
# Current learning rate: 0.0001
# Epoch: 1	Duration: 75.98s	Train loss: 0.2911	Val loss: 0.3825	Val bias:-0.0523	Val Pearson correlation: 7.1812e-01	Val MeanMult: 3.0103
# Current learning rate: 0.0001
# Epoch: 2	Duration: 70.86s	Train loss: 0.2914	Val loss: 0.3858	Val bias:-0.0803	Val Pearson correlation: 7.1825e-01	Val MeanMult: 3.0230
# Current learning rate: 0.0001
# Epoch: 3	Duration: 70.64s	Train loss: 0.2910	Val loss: 0.3851	Val bias:-0.0744	Val Pearson correlation: 7.1822e-01	Val MeanMult: 3.0206
# Current learning rate: 0.0001
# Epoch: 4	Duration: 70.67s	Train loss: 0.2910	Val loss: 0.3829	Val bias:-0.0602	Val Pearson correlation: 7.1843e-01	Val MeanMult: 3.0110
# Current learning rate: 0.0001
# Epoch: 5	Duration: 70.69s	Train loss: 0.2907	Val loss: 0.3853	Val bias:-0.0775	Val Pearson correlation: 7.1821e-01	Val MeanMult: 3.0212
# Current learning rate: 0.0001
# Epoch: 6	Duration: 70.72s	Train loss: 0.2913	Val loss: 0.3838	Val bias:-0.0678	Val Pearson correlation: 7.1833e-01	Val MeanMult: 3.0154
# Current learning rate: 0.0001
# Epoch: 7	Duration: 83.23s	Train loss: 0.2918	Val loss: 0.3841	Val bias:-0.0699	Val Pearson correlation: 7.1831e-01	Val MeanMult: 3.0160
# Current learning rate: 0.0001
# Epoch: 8	Duration: 70.81s	Train loss: 0.2903	Val loss: 0.3865	Val bias:-0.0841	Val Pearson correlation: 7.1837e-01	Val MeanMult: 3.0255
# Current learning rate: 0.0001
# Epoch: 9	Duration: 80.10s	Train loss: 0.2902	Val loss: 0.3836	Val bias:-0.0654	Val Pearson correlation: 7.1832e-01	Val MeanMult: 3.0143
# Current learning rate: 0.0001
# Epoch: 10	Duration: 70.82s	Train loss: 0.2911	Val loss: 0.3833	Val bias:-0.0650	Val Pearson correlation: 7.1852e-01	Val MeanMult: 3.0126
# Current learning rate: 0.0001
# Epoch: 11	Duration: 74.25s	Train loss: 0.2904	Val loss: 0.3834	Val bias:-0.0602	Val Pearson correlation: 7.1826e-01	Val MeanMult: 3.0134
# Current learning rate: 0.0001
# Epoch: 12	Duration: 70.79s	Train loss: 0.2906	Val loss: 0.3848	Val bias:-0.0749	Val Pearson correlation: 7.1850e-01	Val MeanMult: 3.0193
# Current learning rate: 0.0001
# Epoch: 13	Duration: 70.77s	Train loss: 0.2897	Val loss: 0.3856	Val bias:-0.0785	Val Pearson correlation: 7.1838e-01	Val MeanMult: 3.0217
# Current learning rate: 0.0001
# Epoch: 14	Duration: 71.00s	Train loss: 0.2906	Val loss: 0.3861	Val bias:-0.0835	Val Pearson correlation: 7.1845e-01	Val MeanMult: 3.0235
# Current learning rate: 0.0001
# Epoch: 15	Duration: 70.68s	Train loss: 0.2899	Val loss: 0.3845	Val bias:-0.0741	Val Pearson correlation: 7.1858e-01	Val MeanMult: 3.0172
# Current learning rate: 0.0001
# Epoch: 16	Duration: 72.75s	Train loss: 0.2896	Val loss: 0.3835	Val bias:-0.0646	Val Pearson correlation: 7.1846e-01	Val MeanMult: 3.0137
# Current learning rate: 0.0001
# Epoch: 17	Duration: 70.69s	Train loss: 0.2908	Val loss: 0.3837	Val bias:-0.0692	Val Pearson correlation: 7.1886e-01	Val MeanMult: 3.0149
# Current learning rate: 0.0001
# Epoch: 18	Duration: 70.74s	Train loss: 0.2905	Val loss: 0.3844	Val bias:-0.0774	Val Pearson correlation: 7.1889e-01	Val MeanMult: 3.0177
# Current learning rate: 0.0001
# Epoch: 19	Duration: 73.38s	Train loss: 0.2897	Val loss: 0.3840	Val bias:-0.0727	Val Pearson correlation: 7.1881e-01	Val MeanMult: 3.0147
# Current learning rate: 0.0001
# Checkpoint saved at epoch 20
# Epoch: 20	Duration: 71.75s	Train loss: 0.2895	Val loss: 0.3846	Val bias:-0.0694	Val Pearson correlation: 7.1850e-01	Val MeanMult: 3.0176
# Current learning rate: 0.0001
# Epoch: 21	Duration: 70.75s	Train loss: 0.2890	Val loss: 0.3837	Val bias:-0.0669	Val Pearson correlation: 7.1866e-01	Val MeanMult: 3.0145
# Current learning rate: 0.0001
# Epoch: 22	Duration: 76.22s	Train loss: 0.2890	Val loss: 0.3851	Val bias:-0.0785	Val Pearson correlation: 7.1876e-01	Val MeanMult: 3.0191
# Current learning rate: 0.0001
# Epoch: 23	Duration: 71.03s	Train loss: 0.2894	Val loss: 0.3837	Val bias:-0.0696	Val Pearson correlation: 7.1882e-01	Val MeanMult: 3.0141
# Current learning rate: 0.0001
# Epoch: 24	Duration: 70.81s	Train loss: 0.2885	Val loss: 0.3842	Val bias:-0.0731	Val Pearson correlation: 7.1882e-01	Val MeanMult: 3.0163
# Current learning rate: 0.0001
# Epoch: 25	Duration: 71.21s	Train loss: 0.2894	Val loss: 0.3848	Val bias:-0.0763	Val Pearson correlation: 7.1871e-01	Val MeanMult: 3.0180
# Current learning rate: 0.0001
# Epoch: 26	Duration: 70.57s	Train loss: 0.2884	Val loss: 0.3833	Val bias:-0.0687	Val Pearson correlation: 7.1891e-01	Val MeanMult: 3.0127
# Current learning rate: 0.0001
# Epoch: 27	Duration: 70.62s	Train loss: 0.2880	Val loss: 0.3840	Val bias:-0.0689	Val Pearson correlation: 7.1880e-01	Val MeanMult: 3.0166
# Current learning rate: 0.0001
# Epoch: 28	Duration: 70.57s	Train loss: 0.2887	Val loss: 0.3840	Val bias:-0.0710	Val Pearson correlation: 7.1900e-01	Val MeanMult: 3.0155
# Current learning rate: 0.0001
# Epoch: 29	Duration: 70.51s	Train loss: 0.2894	Val loss: 0.3833	Val bias:-0.0688	Val Pearson correlation: 7.1917e-01	Val MeanMult: 3.0122
# Current learning rate: 0.0001
# Epoch: 30	Duration: 70.67s	Train loss: 0.2890	Val loss: 0.3848	Val bias:-0.0777	Val Pearson correlation: 7.1891e-01	Val MeanMult: 3.0186
# Current learning rate: 0.0001
# Epoch: 31	Duration: 70.80s	Train loss: 0.2883	Val loss: 0.3836	Val bias:-0.0693	Val Pearson correlation: 7.1914e-01	Val MeanMult: 3.0128
# Current learning rate: 0.0001
# Epoch: 32	Duration: 70.77s	Train loss: 0.2884	Val loss: 0.3846	Val bias:-0.0738	Val Pearson correlation: 7.1905e-01	Val MeanMult: 3.0167
# Current learning rate: 0.0001
# Epoch: 33	Duration: 70.65s	Train loss: 0.2879	Val loss: 0.3841	Val bias:-0.0728	Val Pearson correlation: 7.1907e-01	Val MeanMult: 3.0149
# Current learning rate: 0.0001
# Epoch: 34	Duration: 71.19s	Train loss: 0.2873	Val loss: 0.3828	Val bias:-0.0609	Val Pearson correlation: 7.1901e-01	Val MeanMult: 3.0111
# Current learning rate: 0.0001
# Epoch: 35	Duration: 70.60s	Train loss: 0.2879	Val loss: 0.3838	Val bias:-0.0714	Val Pearson correlation: 7.1906e-01	Val MeanMult: 3.0139
# Current learning rate: 0.0001
# Epoch: 36	Duration: 70.59s	Train loss: 0.2878	Val loss: 0.3837	Val bias:-0.0721	Val Pearson correlation: 7.1924e-01	Val MeanMult: 3.0138
# Current learning rate: 0.0001
# Epoch: 37	Duration: 70.60s	Train loss: 0.2880	Val loss: 0.3837	Val bias:-0.0719	Val Pearson correlation: 7.1912e-01	Val MeanMult: 3.0139
# Current learning rate: 0.0001
# Epoch: 38	Duration: 70.54s	Train loss: 0.2869	Val loss: 0.3843	Val bias:-0.0666	Val Pearson correlation: 7.1885e-01	Val MeanMult: 3.0169
# Current learning rate: 0.0001
# Epoch: 39	Duration: 71.18s	Train loss: 0.2873	Val loss: 0.3834	Val bias:-0.0687	Val Pearson correlation: 7.1928e-01	Val MeanMult: 3.0127
# Current learning rate: 0.0001
# Checkpoint saved at epoch 40
# Epoch: 40	Duration: 70.80s	Train loss: 0.2864	Val loss: 0.3841	Val bias:-0.0703	Val Pearson correlation: 7.1923e-01	Val MeanMult: 3.0151
# Current learning rate: 0.0001
# Epoch: 41	Duration: 77.00s	Train loss: 0.2880	Val loss: 0.3838	Val bias:-0.0745	Val Pearson correlation: 7.1932e-01	Val MeanMult: 3.0146
# Current learning rate: 0.0001
# Epoch: 42	Duration: 70.93s	Train loss: 0.2877	Val loss: 0.3839	Val bias:-0.0726	Val Pearson correlation: 7.1923e-01	Val MeanMult: 3.0142
# Current learning rate: 0.0001
# Epoch: 43	Duration: 70.90s	Train loss: 0.2873	Val loss: 0.3851	Val bias:-0.0828	Val Pearson correlation: 7.1951e-01	Val MeanMult: 3.0191
# Current learning rate: 0.0001
# Epoch: 44	Duration: 70.91s	Train loss: 0.2875	Val loss: 0.3833	Val bias:-0.0739	Val Pearson correlation: 7.1955e-01	Val MeanMult: 3.0128
# Current learning rate: 0.0001
# Epoch: 45	Duration: 71.40s	Train loss: 0.2862	Val loss: 0.3850	Val bias:-0.0785	Val Pearson correlation: 7.1923e-01	Val MeanMult: 3.0193
# Current learning rate: 0.0001
# Epoch: 46	Duration: 74.73s	Train loss: 0.2864	Val loss: 0.3834	Val bias:-0.0702	Val Pearson correlation: 7.1947e-01	Val MeanMult: 3.0124
# Current learning rate: 0.0001
# Epoch: 47	Duration: 71.43s	Train loss: 0.2868	Val loss: 0.3834	Val bias:-0.0697	Val Pearson correlation: 7.1947e-01	Val MeanMult: 3.0124
# Current learning rate: 0.0001
# Epoch: 48	Duration: 70.88s	Train loss: 0.2868	Val loss: 0.3831	Val bias:-0.0683	Val Pearson correlation: 7.1956e-01	Val MeanMult: 3.0112
# Current learning rate: 0.0001
# Epoch: 49	Duration: 71.14s	Train loss: 0.2862	Val loss: 0.3859	Val bias:-0.0861	Val Pearson correlation: 7.1953e-01	Val MeanMult: 3.0224
# Current learning rate: 5e-05
# Epoch: 50	Duration: 72.22s	Train loss: 0.2820	Val loss: 0.3845	Val bias:-0.0922	Val Pearson correlation: 7.1929e-01	Val MeanMult: 3.0197
# Current learning rate: 5e-05
# Epoch: 51	Duration: 70.72s	Train loss: 0.2818	Val loss: 0.3851	Val bias:-0.0955	Val Pearson correlation: 7.1914e-01	Val MeanMult: 3.0230
# Current learning rate: 5e-05
# Epoch: 52	Duration: 70.88s	Train loss: 0.2817	Val loss: 0.3868	Val bias:-0.1026	Val Pearson correlation: 7.1899e-01	Val MeanMult: 3.0304
# Current learning rate: 5e-05
# Epoch: 53	Duration: 73.42s	Train loss: 0.2827	Val loss: 0.3855	Val bias:-0.0970	Val Pearson correlation: 7.1906e-01	Val MeanMult: 3.0246
# Current learning rate: 5e-05
# Epoch: 54	Duration: 71.08s	Train loss: 0.2825	Val loss: 0.3879	Val bias:-0.1065	Val Pearson correlation: 7.1892e-01	Val MeanMult: 3.0346
# Current learning rate: 5e-05
# Epoch: 55	Duration: 70.86s	Train loss: 0.2821	Val loss: 0.3881	Val bias:-0.1083	Val Pearson correlation: 7.1880e-01	Val MeanMult: 3.0362
# Current learning rate: 5e-05
# Epoch: 56	Duration: 70.93s	Train loss: 0.2816	Val loss: 0.3872	Val bias:-0.1028	Val Pearson correlation: 7.1880e-01	Val MeanMult: 3.0310
# Current learning rate: 5e-05
# Epoch: 57	Duration: 72.86s	Train loss: 0.2820	Val loss: 0.3893	Val bias:-0.1149	Val Pearson correlation: 7.1901e-01	Val MeanMult: 3.0405
# Current learning rate: 5e-05
# Epoch: 58	Duration: 70.87s	Train loss: 0.2814	Val loss: 0.3893	Val bias:-0.1134	Val Pearson correlation: 7.1882e-01	Val MeanMult: 3.0405
# Current learning rate: 5e-05
# Epoch: 59	Duration: 80.10s	Train loss: 0.2811	Val loss: 0.3881	Val bias:-0.1076	Val Pearson correlation: 7.1883e-01	Val MeanMult: 3.0348
# Current learning rate: 5e-05
# Checkpoint saved at epoch 60
# Epoch: 60	Duration: 70.58s	Train loss: 0.2822	Val loss: 0.3894	Val bias:-0.1134	Val Pearson correlation: 7.1889e-01	Val MeanMult: 3.0403
# Current learning rate: 5e-05
# Epoch: 61	Duration: 70.78s	Train loss: 0.2820	Val loss: 0.3904	Val bias:-0.1183	Val Pearson correlation: 7.1885e-01	Val MeanMult: 3.0454
# Current learning rate: 5e-05
# Epoch: 62	Duration: 70.71s	Train loss: 0.2815	Val loss: 0.3880	Val bias:-0.1073	Val Pearson correlation: 7.1901e-01	Val MeanMult: 3.0346
# Current learning rate: 5e-05
# Epoch: 63	Duration: 70.78s	Train loss: 0.2816	Val loss: 0.3903	Val bias:-0.1172	Val Pearson correlation: 7.1885e-01	Val MeanMult: 3.0444
# Current learning rate: 5e-05
# Epoch: 64	Duration: 70.67s	Train loss: 0.2812	Val loss: 0.3886	Val bias:-0.1099	Val Pearson correlation: 7.1890e-01	Val MeanMult: 3.0367
# Current learning rate: 5e-05
# Epoch: 65	Duration: 70.65s	Train loss: 0.2811	Val loss: 0.3898	Val bias:-0.1163	Val Pearson correlation: 7.1900e-01	Val MeanMult: 3.0420
# Current learning rate: 5e-05
# Epoch: 66	Duration: 71.29s	Train loss: 0.2811	Val loss: 0.3879	Val bias:-0.1073	Val Pearson correlation: 7.1909e-01	Val MeanMult: 3.0341
# Current learning rate: 5e-05
# Epoch: 67	Duration: 70.70s	Train loss: 0.2810	Val loss: 0.3881	Val bias:-0.1075	Val Pearson correlation: 7.1897e-01	Val MeanMult: 3.0342
# Current learning rate: 5e-05
# Epoch: 68	Duration: 71.03s	Train loss: 0.2806	Val loss: 0.3905	Val bias:-0.1179	Val Pearson correlation: 7.1896e-01	Val MeanMult: 3.0455
# Current learning rate: 5e-05
# Epoch: 69	Duration: 74.71s	Train loss: 0.2807	Val loss: 0.3890	Val bias:-0.1111	Val Pearson correlation: 7.1884e-01	Val MeanMult: 3.0386
# Current learning rate: 5e-05
# Epoch: 70	Duration: 70.68s	Train loss: 0.2812	Val loss: 0.3888	Val bias:-0.1123	Val Pearson correlation: 7.1904e-01	Val MeanMult: 3.0382
# Current learning rate: 5e-05
# Epoch: 71	Duration: 70.71s	Train loss: 0.2809	Val loss: 0.3894	Val bias:-0.1135	Val Pearson correlation: 7.1884e-01	Val MeanMult: 3.0401
# Current learning rate: 5e-05
# Epoch: 72	Duration: 70.68s	Train loss: 0.2800	Val loss: 0.3911	Val bias:-0.1198	Val Pearson correlation: 7.1888e-01	Val MeanMult: 3.0474
# Current learning rate: 5e-05
# Epoch: 73	Duration: 70.80s	Train loss: 0.2806	Val loss: 0.3874	Val bias:-0.1046	Val Pearson correlation: 7.1908e-01	Val MeanMult: 3.0305
# Current learning rate: 5e-05
# Epoch: 74	Duration: 78.34s	Train loss: 0.2807	Val loss: 0.3876	Val bias:-0.1060	Val Pearson correlation: 7.1916e-01	Val MeanMult: 3.0328
# Current learning rate: 5e-05
# Epoch: 75	Duration: 70.93s	Train loss: 0.2801	Val loss: 0.3886	Val bias:-0.1111	Val Pearson correlation: 7.1897e-01	Val MeanMult: 3.0373
# Current learning rate: 5e-05
# Epoch: 76	Duration: 70.65s	Train loss: 0.2810	Val loss: 0.3883	Val bias:-0.1099	Val Pearson correlation: 7.1920e-01	Val MeanMult: 3.0352
# Current learning rate: 5e-05
# Epoch: 77	Duration: 71.18s	Train loss: 0.2801	Val loss: 0.3896	Val bias:-0.1144	Val Pearson correlation: 7.1908e-01	Val MeanMult: 3.0406
# Current learning rate: 5e-05
# Epoch: 78	Duration: 70.79s	Train loss: 0.2798	Val loss: 0.3892	Val bias:-0.1129	Val Pearson correlation: 7.1917e-01	Val MeanMult: 3.0386
# Current learning rate: 5e-05
# Epoch: 79	Duration: 71.20s	Train loss: 0.2801	Val loss: 0.3878	Val bias:-0.1068	Val Pearson correlation: 7.1924e-01	Val MeanMult: 3.0331
# Current learning rate: 5e-05
# Checkpoint saved at epoch 80
# Epoch: 80	Duration: 77.66s	Train loss: 0.2797	Val loss: 0.3889	Val bias:-0.1120	Val Pearson correlation: 7.1913e-01	Val MeanMult: 3.0380
# Current learning rate: 5e-05
# Epoch: 81	Duration: 75.19s	Train loss: 0.2804	Val loss: 0.3869	Val bias:-0.1034	Val Pearson correlation: 7.1938e-01	Val MeanMult: 3.0287
# Current learning rate: 5e-05
# Epoch: 82	Duration: 70.94s	Train loss: 0.2803	Val loss: 0.3887	Val bias:-0.1123	Val Pearson correlation: 7.1918e-01	Val MeanMult: 3.0375
# Current learning rate: 5e-05
# Epoch: 83	Duration: 76.98s	Train loss: 0.2794	Val loss: 0.3891	Val bias:-0.1130	Val Pearson correlation: 7.1925e-01	Val MeanMult: 3.0381
# Current learning rate: 5e-05
# Epoch: 84	Duration: 70.79s	Train loss: 0.2806	Val loss: 0.3906	Val bias:-0.1212	Val Pearson correlation: 7.1943e-01	Val MeanMult: 3.0448
# Current learning rate: 5e-05
# Epoch: 85	Duration: 70.91s	Train loss: 0.2796	Val loss: 0.3890	Val bias:-0.1135	Val Pearson correlation: 7.1928e-01	Val MeanMult: 3.0379
# Current learning rate: 5e-05
# Epoch: 86	Duration: 75.90s	Train loss: 0.2793	Val loss: 0.3893	Val bias:-0.1144	Val Pearson correlation: 7.1935e-01	Val MeanMult: 3.0391
# Current learning rate: 5e-05
# Epoch: 87	Duration: 70.77s	Train loss: 0.2792	Val loss: 0.3902	Val bias:-0.1190	Val Pearson correlation: 7.1949e-01	Val MeanMult: 3.0432
# Current learning rate: 5e-05
# Epoch: 88	Duration: 71.12s	Train loss: 0.2796	Val loss: 0.3891	Val bias:-0.1133	Val Pearson correlation: 7.1940e-01	Val MeanMult: 3.0384
# Current learning rate: 5e-05
# Epoch: 89	Duration: 82.76s	Train loss: 0.2796	Val loss: 0.3884	Val bias:-0.1117	Val Pearson correlation: 7.1939e-01	Val MeanMult: 3.0361
# Current learning rate: 5e-05
# Epoch: 90	Duration: 109.69s	Train loss: 0.2801	Val loss: 0.3891	Val bias:-0.1153	Val Pearson correlation: 7.1953e-01	Val MeanMult: 3.0388
# Current learning rate: 5e-05
# Epoch: 91	Duration: 71.31s	Train loss: 0.2788	Val loss: 0.3896	Val bias:-0.1157	Val Pearson correlation: 7.1937e-01	Val MeanMult: 3.0405
# Current learning rate: 5e-05
# Epoch: 92	Duration: 76.11s	Train loss: 0.2793	Val loss: 0.3889	Val bias:-0.1130	Val Pearson correlation: 7.1944e-01	Val MeanMult: 3.0378
# Current learning rate: 5e-05
# Epoch: 93	Duration: 81.39s	Train loss: 0.2789	Val loss: 0.3891	Val bias:-0.1148	Val Pearson correlation: 7.1949e-01	Val MeanMult: 3.0384
# Current learning rate: 5e-05
# Epoch: 94	Duration: 70.89s	Train loss: 0.2793	Val loss: 0.3898	Val bias:-0.1173	Val Pearson correlation: 7.1947e-01	Val MeanMult: 3.0411
# Current learning rate: 5e-05
# Epoch: 95	Duration: 87.06s	Train loss: 0.2794	Val loss: 0.3891	Val bias:-0.1142	Val Pearson correlation: 7.1961e-01	Val MeanMult: 3.0381
# Current learning rate: 5e-05
# Epoch: 96	Duration: 100.14s	Train loss: 0.2783	Val loss: 0.3886	Val bias:-0.1117	Val Pearson correlation: 7.1956e-01	Val MeanMult: 3.0358
# Current learning rate: 5e-05
# Epoch: 97	Duration: 71.42s	Train loss: 0.2789	Val loss: 0.3898	Val bias:-0.1184	Val Pearson correlation: 7.1945e-01	Val MeanMult: 3.0423
# Current learning rate: 5e-05
# Epoch: 98	Duration: 70.88s	Train loss: 0.2791	Val loss: 0.3901	Val bias:-0.1186	Val Pearson correlation: 7.1953e-01	Val MeanMult: 3.0423
# Current learning rate: 5e-05
# Epoch: 99	Duration: 71.66s	Train loss: 0.2792	Val loss: 0.3877	Val bias:-0.1079	Val Pearson correlation: 7.1948e-01	Val MeanMult: 3.0325
# Current learning rate: 2.5e-05
# Checkpoint saved at epoch 100
# Epoch: 100	Duration: 83.45s	Train loss: 0.2756	Val loss: 0.3749	Val bias:-0.0271	Val Pearson correlation: 7.2041e-01	Val MeanMult: 2.9827
# Current learning rate: 2.5e-05
# Epoch: 101	Duration: 70.97s	Train loss: 0.2756	Val loss: 0.3751	Val bias:-0.0333	Val Pearson correlation: 7.2050e-01	Val MeanMult: 2.9833
# Current learning rate: 2.5e-05
# Epoch: 102	Duration: 70.65s	Train loss: 0.2754	Val loss: 0.3750	Val bias:-0.0340	Val Pearson correlation: 7.2049e-01	Val MeanMult: 2.9830
# Current learning rate: 2.5e-05
# Epoch: 103	Duration: 71.18s	Train loss: 0.2763	Val loss: 0.3750	Val bias:-0.0352	Val Pearson correlation: 7.2053e-01	Val MeanMult: 2.9823
# Current learning rate: 2.5e-05
# Epoch: 104	Duration: 86.05s	Train loss: 0.2754	Val loss: 0.3748	Val bias:-0.0334	Val Pearson correlation: 7.2065e-01	Val MeanMult: 2.9813
# Current learning rate: 2.5e-05
# Epoch: 105	Duration: 70.93s	Train loss: 0.2765	Val loss: 0.3745	Val bias:-0.0302	Val Pearson correlation: 7.2067e-01	Val MeanMult: 2.9810
# Current learning rate: 2.5e-05
# Epoch: 106	Duration: 71.06s	Train loss: 0.2756	Val loss: 0.3752	Val bias:-0.0370	Val Pearson correlation: 7.2053e-01	Val MeanMult: 2.9829
# Current learning rate: 2.5e-05
# Epoch: 107	Duration: 74.67s	Train loss: 0.2756	Val loss: 0.3757	Val bias:-0.0416	Val Pearson correlation: 7.2053e-01	Val MeanMult: 2.9844
# Current learning rate: 2.5e-05
# Epoch: 108	Duration: 72.76s	Train loss: 0.2752	Val loss: 0.3752	Val bias:-0.0343	Val Pearson correlation: 7.2047e-01	Val MeanMult: 2.9830
# Current learning rate: 2.5e-05
# Epoch: 109	Duration: 70.74s	Train loss: 0.2742	Val loss: 0.3750	Val bias:-0.0293	Val Pearson correlation: 7.2045e-01	Val MeanMult: 2.9825
# Current learning rate: 2.5e-05
# Epoch: 110	Duration: 80.73s	Train loss: 0.2762	Val loss: 0.3749	Val bias:-0.0320	Val Pearson correlation: 7.2050e-01	Val MeanMult: 2.9820
# Current learning rate: 2.5e-05
# Epoch: 111	Duration: 72.23s	Train loss: 0.2750	Val loss: 0.3751	Val bias:-0.0315	Val Pearson correlation: 7.2048e-01	Val MeanMult: 2.9821
# Current learning rate: 2.5e-05
# Epoch: 112	Duration: 72.08s	Train loss: 0.2752	Val loss: 0.3758	Val bias:-0.0408	Val Pearson correlation: 7.2045e-01	Val MeanMult: 2.9847
# Current learning rate: 2.5e-05
# Epoch: 113	Duration: 93.42s	Train loss: 0.2755	Val loss: 0.3754	Val bias:-0.0389	Val Pearson correlation: 7.2051e-01	Val MeanMult: 2.9835
# Current learning rate: 2.5e-05
# Epoch: 114	Duration: 70.76s	Train loss: 0.2760	Val loss: 0.3754	Val bias:-0.0395	Val Pearson correlation: 7.2060e-01	Val MeanMult: 2.9835
# Current learning rate: 2.5e-05
# Epoch: 115	Duration: 82.06s	Train loss: 0.2749	Val loss: 0.3754	Val bias:-0.0370	Val Pearson correlation: 7.2044e-01	Val MeanMult: 2.9830
# Current learning rate: 2.5e-05
# Epoch: 116	Duration: 70.67s	Train loss: 0.2757	Val loss: 0.3752	Val bias:-0.0359	Val Pearson correlation: 7.2052e-01	Val MeanMult: 2.9827
# Current learning rate: 2.5e-05
# Epoch: 117	Duration: 71.36s	Train loss: 0.2751	Val loss: 0.3755	Val bias:-0.0373	Val Pearson correlation: 7.2053e-01	Val MeanMult: 2.9836
# Current learning rate: 2.5e-05
# Epoch: 118	Duration: 71.55s	Train loss: 0.2754	Val loss: 0.3754	Val bias:-0.0378	Val Pearson correlation: 7.2057e-01	Val MeanMult: 2.9832
# Current learning rate: 2.5e-05
# Epoch: 119	Duration: 70.57s	Train loss: 0.2752	Val loss: 0.3756	Val bias:-0.0413	Val Pearson correlation: 7.2064e-01	Val MeanMult: 2.9835
# Current learning rate: 2.5e-05
# Checkpoint saved at epoch 120
# Epoch: 120	Duration: 70.67s	Train loss: 0.2747	Val loss: 0.3752	Val bias:-0.0357	Val Pearson correlation: 7.2050e-01	Val MeanMult: 2.9828
# Current learning rate: 2.5e-05
# Epoch: 121	Duration: 94.15s	Train loss: 0.2752	Val loss: 0.3752	Val bias:-0.0383	Val Pearson correlation: 7.2066e-01	Val MeanMult: 2.9827
# Current learning rate: 2.5e-05
# Epoch: 122	Duration: 104.53s	Train loss: 0.2752	Val loss: 0.3754	Val bias:-0.0377	Val Pearson correlation: 7.2052e-01	Val MeanMult: 2.9830
# Current learning rate: 2.5e-05
# Epoch: 123	Duration: 70.74s	Train loss: 0.2746	Val loss: 0.3760	Val bias:-0.0433	Val Pearson correlation: 7.2046e-01	Val MeanMult: 2.9850
# Current learning rate: 2.5e-05
# Epoch: 124	Duration: 75.32s	Train loss: 0.2745	Val loss: 0.3762	Val bias:-0.0485	Val Pearson correlation: 7.2056e-01	Val MeanMult: 2.9857
# Current learning rate: 2.5e-05
# Epoch: 125	Duration: 70.62s	Train loss: 0.2749	Val loss: 0.3751	Val bias:-0.0347	Val Pearson correlation: 7.2060e-01	Val MeanMult: 2.9823
# Current learning rate: 2.5e-05
# Epoch: 126	Duration: 70.67s	Train loss: 0.2749	Val loss: 0.3752	Val bias:-0.0358	Val Pearson correlation: 7.2066e-01	Val MeanMult: 2.9823
# Current learning rate: 2.5e-05
# Epoch: 127	Duration: 70.56s	Train loss: 0.2755	Val loss: 0.3763	Val bias:-0.0502	Val Pearson correlation: 7.2061e-01	Val MeanMult: 2.9865
# Current learning rate: 2.5e-05
# Epoch: 128	Duration: 71.29s	Train loss: 0.2748	Val loss: 0.3756	Val bias:-0.0411	Val Pearson correlation: 7.2056e-01	Val MeanMult: 2.9833
# Current learning rate: 2.5e-05
# Epoch: 129	Duration: 70.88s	Train loss: 0.2751	Val loss: 0.3755	Val bias:-0.0394	Val Pearson correlation: 7.2057e-01	Val MeanMult: 2.9833
# Current learning rate: 2.5e-05
# Epoch: 130	Duration: 73.77s	Train loss: 0.2752	Val loss: 0.3756	Val bias:-0.0398	Val Pearson correlation: 7.2050e-01	Val MeanMult: 2.9839
# Current learning rate: 2.5e-05
# Epoch: 131	Duration: 70.98s	Train loss: 0.2745	Val loss: 0.3755	Val bias:-0.0411	Val Pearson correlation: 7.2057e-01	Val MeanMult: 2.9836
# Current learning rate: 2.5e-05
# Epoch: 132	Duration: 70.79s	Train loss: 0.2749	Val loss: 0.3758	Val bias:-0.0429	Val Pearson correlation: 7.2057e-01	Val MeanMult: 2.9842
# Current learning rate: 2.5e-05
# Epoch: 133	Duration: 70.97s	Train loss: 0.2747	Val loss: 0.3759	Val bias:-0.0435	Val Pearson correlation: 7.2043e-01	Val MeanMult: 2.9851
# Current learning rate: 2.5e-05
# Epoch: 134	Duration: 80.12s	Train loss: 0.2753	Val loss: 0.3755	Val bias:-0.0422	Val Pearson correlation: 7.2066e-01	Val MeanMult: 2.9831
# Current learning rate: 2.5e-05
# Epoch: 135	Duration: 70.75s	Train loss: 0.2744	Val loss: 0.3755	Val bias:-0.0397	Val Pearson correlation: 7.2068e-01	Val MeanMult: 2.9837
# Current learning rate: 2.5e-05
# Epoch: 136	Duration: 72.01s	Train loss: 0.2744	Val loss: 0.3758	Val bias:-0.0423	Val Pearson correlation: 7.2060e-01	Val MeanMult: 2.9845
# Current learning rate: 2.5e-05
# Epoch: 137	Duration: 73.70s	Train loss: 0.2746	Val loss: 0.3759	Val bias:-0.0435	Val Pearson correlation: 7.2062e-01	Val MeanMult: 2.9845
# Current learning rate: 2.5e-05
# Epoch: 138	Duration: 70.68s	Train loss: 0.2751	Val loss: 0.3759	Val bias:-0.0465	Val Pearson correlation: 7.2074e-01	Val MeanMult: 2.9849
# Current learning rate: 2.5e-05
# Epoch: 139	Duration: 70.79s	Train loss: 0.2748	Val loss: 0.3753	Val bias:-0.0393	Val Pearson correlation: 7.2072e-01	Val MeanMult: 2.9829
# Current learning rate: 2.5e-05
# Checkpoint saved at epoch 140
# Epoch: 140	Duration: 71.06s	Train loss: 0.2744	Val loss: 0.3756	Val bias:-0.0425	Val Pearson correlation: 7.2077e-01	Val MeanMult: 2.9837
# Current learning rate: 2.5e-05
# Epoch: 141	Duration: 70.55s	Train loss: 0.2741	Val loss: 0.3757	Val bias:-0.0440	Val Pearson correlation: 7.2080e-01	Val MeanMult: 2.9843
# Current learning rate: 2.5e-05
# Epoch: 142	Duration: 92.45s	Train loss: 0.2740	Val loss: 0.3757	Val bias:-0.0426	Val Pearson correlation: 7.2082e-01	Val MeanMult: 2.9835
# Current learning rate: 2.5e-05
# Epoch: 143	Duration: 71.38s	Train loss: 0.2737	Val loss: 0.3758	Val bias:-0.0447	Val Pearson correlation: 7.2074e-01	Val MeanMult: 2.9849
# Current learning rate: 2.5e-05
# Epoch: 144	Duration: 71.40s	Train loss: 0.2737	Val loss: 0.3757	Val bias:-0.0437	Val Pearson correlation: 7.2069e-01	Val MeanMult: 2.9845
# Current learning rate: 2.5e-05
# Epoch: 145	Duration: 85.00s	Train loss: 0.2740	Val loss: 0.3755	Val bias:-0.0388	Val Pearson correlation: 7.2059e-01	Val MeanMult: 2.9841
# Current learning rate: 2.5e-05
# Epoch: 146	Duration: 75.99s	Train loss: 0.2740	Val loss: 0.3756	Val bias:-0.0429	Val Pearson correlation: 7.2070e-01	Val MeanMult: 2.9838
# Current learning rate: 2.5e-05
# Epoch: 147	Duration: 71.28s	Train loss: 0.2743	Val loss: 0.3761	Val bias:-0.0461	Val Pearson correlation: 7.2061e-01	Val MeanMult: 2.9858
# Current learning rate: 2.5e-05
# Epoch: 148	Duration: 70.63s	Train loss: 0.2740	Val loss: 0.3756	Val bias:-0.0399	Val Pearson correlation: 7.2070e-01	Val MeanMult: 2.9834
# Current learning rate: 2.5e-05
# Epoch: 149	Duration: 77.12s	Train loss: 0.2741	Val loss: 0.3758	Val bias:-0.0437	Val Pearson correlation: 7.2074e-01	Val MeanMult: 2.9842
# Current learning rate: 1.25e-05
# Epoch: 150	Duration: 71.12s	Train loss: 0.2713	Val loss: 0.3729	Val bias:-0.0008	Val Pearson correlation: 7.2114e-01	Val MeanMult: 2.9772
# Current learning rate: 1.25e-05
# Epoch: 151	Duration: 70.54s	Train loss: 0.2720	Val loss: 0.3730	Val bias:0.0029	Val Pearson correlation: 7.2114e-01	Val MeanMult: 2.9791
# Current learning rate: 1.25e-05
# Epoch: 152	Duration: 82.20s	Train loss: 0.2720	Val loss: 0.3729	Val bias:-0.0020	Val Pearson correlation: 7.2115e-01	Val MeanMult: 2.9777
# Current learning rate: 1.25e-05
# Epoch: 153	Duration: 70.65s	Train loss: 0.2717	Val loss: 0.3730	Val bias:-0.0042	Val Pearson correlation: 7.2103e-01	Val MeanMult: 2.9773
# Current learning rate: 1.25e-05
# Epoch: 154	Duration: 71.37s	Train loss: 0.2721	Val loss: 0.3729	Val bias:-0.0029	Val Pearson correlation: 7.2110e-01	Val MeanMult: 2.9772
# Current learning rate: 1.25e-05
# Epoch: 155	Duration: 71.17s	Train loss: 0.2722	Val loss: 0.3728	Val bias:-0.0042	Val Pearson correlation: 7.2117e-01	Val MeanMult: 2.9769
# Current learning rate: 1.25e-05
# Epoch: 156	Duration: 91.04s	Train loss: 0.2717	Val loss: 0.3727	Val bias:-0.0067	Val Pearson correlation: 7.2115e-01	Val MeanMult: 2.9762
# Current learning rate: 1.25e-05
# Epoch: 157	Duration: 70.80s	Train loss: 0.2725	Val loss: 0.3727	Val bias:-0.0094	Val Pearson correlation: 7.2123e-01	Val MeanMult: 2.9759
# Current learning rate: 1.25e-05
# Epoch: 158	Duration: 71.22s	Train loss: 0.2716	Val loss: 0.3727	Val bias:-0.0025	Val Pearson correlation: 7.2125e-01	Val MeanMult: 2.9775
# Current learning rate: 1.25e-05
# Epoch: 159	Duration: 71.08s	Train loss: 0.2714	Val loss: 0.3727	Val bias:-0.0065	Val Pearson correlation: 7.2126e-01	Val MeanMult: 2.9760
# Current learning rate: 1.25e-05
# Checkpoint saved at epoch 160
# Epoch: 160	Duration: 73.04s	Train loss: 0.2716	Val loss: 0.3727	Val bias:-0.0037	Val Pearson correlation: 7.2125e-01	Val MeanMult: 2.9764
# Current learning rate: 1.25e-05
# Epoch: 161	Duration: 71.63s	Train loss: 0.2716	Val loss: 0.3728	Val bias:-0.0080	Val Pearson correlation: 7.2124e-01	Val MeanMult: 2.9761
# Current learning rate: 1.25e-05
# Epoch: 162	Duration: 71.26s	Train loss: 0.2717	Val loss: 0.3729	Val bias:-0.0060	Val Pearson correlation: 7.2115e-01	Val MeanMult: 2.9767
# Current learning rate: 1.25e-05
# Epoch: 163	Duration: 70.87s	Train loss: 0.2719	Val loss: 0.3728	Val bias:-0.0066	Val Pearson correlation: 7.2126e-01	Val MeanMult: 2.9762
# Current learning rate: 1.25e-05
# Epoch: 164	Duration: 74.05s	Train loss: 0.2720	Val loss: 0.3728	Val bias:-0.0076	Val Pearson correlation: 7.2117e-01	Val MeanMult: 2.9765
# Current learning rate: 1.25e-05
# Epoch: 165	Duration: 70.86s	Train loss: 0.2717	Val loss: 0.3729	Val bias:-0.0105	Val Pearson correlation: 7.2120e-01	Val MeanMult: 2.9764
# Current learning rate: 1.25e-05
# Epoch: 166	Duration: 75.36s	Train loss: 0.2716	Val loss: 0.3727	Val bias:-0.0077	Val Pearson correlation: 7.2116e-01	Val MeanMult: 2.9765
# Current learning rate: 1.25e-05
# Epoch: 167	Duration: 71.63s	Train loss: 0.2716	Val loss: 0.3728	Val bias:-0.0120	Val Pearson correlation: 7.2118e-01	Val MeanMult: 2.9761
# Current learning rate: 1.25e-05
# Epoch: 168	Duration: 100.20s	Train loss: 0.2714	Val loss: 0.3730	Val bias:-0.0118	Val Pearson correlation: 7.2118e-01	Val MeanMult: 2.9765
# Current learning rate: 1.25e-05
# Epoch: 169	Duration: 71.73s	Train loss: 0.2715	Val loss: 0.3729	Val bias:-0.0079	Val Pearson correlation: 7.2123e-01	Val MeanMult: 2.9765
# Current learning rate: 1.25e-05
# Epoch: 170	Duration: 71.04s	Train loss: 0.2716	Val loss: 0.3728	Val bias:-0.0082	Val Pearson correlation: 7.2117e-01	Val MeanMult: 2.9763
# Current learning rate: 1.25e-05
# Epoch: 171	Duration: 96.18s	Train loss: 0.2716	Val loss: 0.3727	Val bias:-0.0085	Val Pearson correlation: 7.2121e-01	Val MeanMult: 2.9763
# Current learning rate: 1.25e-05
# Epoch: 172	Duration: 71.51s	Train loss: 0.2716	Val loss: 0.3726	Val bias:-0.0060	Val Pearson correlation: 7.2128e-01	Val MeanMult: 2.9757
# Current learning rate: 1.25e-05
# Epoch: 173	Duration: 71.25s	Train loss: 0.2715	Val loss: 0.3727	Val bias:-0.0098	Val Pearson correlation: 7.2126e-01	Val MeanMult: 2.9758
# Current learning rate: 1.25e-05
# Epoch: 174	Duration: 88.03s	Train loss: 0.2716	Val loss: 0.3728	Val bias:-0.0101	Val Pearson correlation: 7.2120e-01	Val MeanMult: 2.9761
# Current learning rate: 1.25e-05
# Epoch: 175	Duration: 71.56s	Train loss: 0.2718	Val loss: 0.3727	Val bias:-0.0069	Val Pearson correlation: 7.2125e-01	Val MeanMult: 2.9760
# Current learning rate: 1.25e-05
# Epoch: 176	Duration: 71.45s	Train loss: 0.2714	Val loss: 0.3728	Val bias:-0.0101	Val Pearson correlation: 7.2121e-01	Val MeanMult: 2.9757
# Current learning rate: 1.25e-05
# Epoch: 177	Duration: 71.19s	Train loss: 0.2720	Val loss: 0.3727	Val bias:-0.0104	Val Pearson correlation: 7.2123e-01	Val MeanMult: 2.9756
# Current learning rate: 1.25e-05
# Epoch: 178	Duration: 73.25s	Train loss: 0.2714	Val loss: 0.3728	Val bias:-0.0086	Val Pearson correlation: 7.2118e-01	Val MeanMult: 2.9762
# Current learning rate: 1.25e-05
# Epoch: 179	Duration: 84.90s	Train loss: 0.2716	Val loss: 0.3728	Val bias:-0.0044	Val Pearson correlation: 7.2125e-01	Val MeanMult: 2.9767
# Current learning rate: 1.25e-05
# Checkpoint saved at epoch 180
# Epoch: 180	Duration: 71.58s	Train loss: 0.2717	Val loss: 0.3728	Val bias:-0.0111	Val Pearson correlation: 7.2127e-01	Val MeanMult: 2.9760
# Current learning rate: 1.25e-05
# Epoch: 181	Duration: 71.05s	Train loss: 0.2716	Val loss: 0.3727	Val bias:-0.0084	Val Pearson correlation: 7.2128e-01	Val MeanMult: 2.9761
# Current learning rate: 1.25e-05
# Epoch: 182	Duration: 70.88s	Train loss: 0.2714	Val loss: 0.3727	Val bias:-0.0084	Val Pearson correlation: 7.2131e-01	Val MeanMult: 2.9757
# Current learning rate: 1.25e-05
# Epoch: 183	Duration: 72.00s	Train loss: 0.2710	Val loss: 0.3727	Val bias:-0.0067	Val Pearson correlation: 7.2135e-01	Val MeanMult: 2.9763
# Current learning rate: 1.25e-05
# Epoch: 184	Duration: 71.57s	Train loss: 0.2714	Val loss: 0.3727	Val bias:-0.0037	Val Pearson correlation: 7.2134e-01	Val MeanMult: 2.9764
# Current learning rate: 1.25e-05
# Epoch: 185	Duration: 71.24s	Train loss: 0.2715	Val loss: 0.3727	Val bias:-0.0072	Val Pearson correlation: 7.2135e-01	Val MeanMult: 2.9763
# Current learning rate: 1.25e-05
# Epoch: 186	Duration: 71.20s	Train loss: 0.2711	Val loss: 0.3726	Val bias:-0.0087	Val Pearson correlation: 7.2131e-01	Val MeanMult: 2.9758
# Current learning rate: 1.25e-05
# Epoch: 187	Duration: 71.52s	Train loss: 0.2708	Val loss: 0.3728	Val bias:-0.0110	Val Pearson correlation: 7.2133e-01	Val MeanMult: 2.9754
# Current learning rate: 1.25e-05
# Epoch: 188	Duration: 80.97s	Train loss: 0.2711	Val loss: 0.3727	Val bias:-0.0076	Val Pearson correlation: 7.2134e-01	Val MeanMult: 2.9757
# Current learning rate: 1.25e-05
# Epoch: 189	Duration: 71.90s	Train loss: 0.2712	Val loss: 0.3726	Val bias:-0.0122	Val Pearson correlation: 7.2138e-01	Val MeanMult: 2.9752
# Current learning rate: 1.25e-05
# Epoch: 190	Duration: 74.21s	Train loss: 0.2715	Val loss: 0.3727	Val bias:-0.0100	Val Pearson correlation: 7.2136e-01	Val MeanMult: 2.9754
# Current learning rate: 1.25e-05
# Epoch: 191	Duration: 70.92s	Train loss: 0.2718	Val loss: 0.3726	Val bias:-0.0086	Val Pearson correlation: 7.2137e-01	Val MeanMult: 2.9750
# Current learning rate: 1.25e-05
# Epoch: 192	Duration: 70.98s	Train loss: 0.2708	Val loss: 0.3727	Val bias:-0.0102	Val Pearson correlation: 7.2137e-01	Val MeanMult: 2.9753
# Current learning rate: 1.25e-05
# Epoch: 193	Duration: 70.77s	Train loss: 0.2712	Val loss: 0.3727	Val bias:-0.0090	Val Pearson correlation: 7.2138e-01	Val MeanMult: 2.9752
# Current learning rate: 1.25e-05
# Epoch: 194	Duration: 70.62s	Train loss: 0.2706	Val loss: 0.3727	Val bias:-0.0105	Val Pearson correlation: 7.2141e-01	Val MeanMult: 2.9753
# Current learning rate: 1.25e-05
# Epoch: 195	Duration: 71.18s	Train loss: 0.2714	Val loss: 0.3727	Val bias:-0.0105	Val Pearson correlation: 7.2143e-01	Val MeanMult: 2.9753
# Current learning rate: 1.25e-05
# Epoch: 196	Duration: 71.31s	Train loss: 0.2705	Val loss: 0.3726	Val bias:-0.0096	Val Pearson correlation: 7.2130e-01	Val MeanMult: 2.9755
# Current learning rate: 1.25e-05
# Epoch: 197	Duration: 70.79s	Train loss: 0.2705	Val loss: 0.3729	Val bias:-0.0160	Val Pearson correlation: 7.2132e-01	Val MeanMult: 2.9754
# Current learning rate: 1.25e-05
# Epoch: 198	Duration: 71.64s	Train loss: 0.2706	Val loss: 0.3726	Val bias:-0.0110	Val Pearson correlation: 7.2135e-01	Val MeanMult: 2.9752
# Current learning rate: 1.25e-05
# Epoch: 199	Duration: 70.91s	Train loss: 0.2710	Val loss: 0.3727	Val bias:-0.0136	Val Pearson correlation: 7.2136e-01	Val MeanMult: 2.9755
# Current learning rate: 6.25e-06
# Checkpoint saved at epoch 200
# Epoch: 200	Duration: 76.48s	Train loss: 0.2711	Val loss: 0.3723	Val bias:0.0094	Val Pearson correlation: 7.2162e-01	Val MeanMult: 2.9777
# Current learning rate: 6.25e-06
# Epoch: 201	Duration: 79.70s	Train loss: 0.2708	Val loss: 0.3721	Val bias:0.0090	Val Pearson correlation: 7.2172e-01	Val MeanMult: 2.9768
# Current learning rate: 6.25e-06
# Epoch: 202	Duration: 71.28s	Train loss: 0.2704	Val loss: 0.3720	Val bias:0.0101	Val Pearson correlation: 7.2174e-01	Val MeanMult: 2.9768
# Current learning rate: 6.25e-06
# Epoch: 203	Duration: 72.56s	Train loss: 0.2707	Val loss: 0.3719	Val bias:0.0057	Val Pearson correlation: 7.2176e-01	Val MeanMult: 2.9752
# Current learning rate: 6.25e-06
# Epoch: 204	Duration: 109.19s	Train loss: 0.2703	Val loss: 0.3719	Val bias:0.0080	Val Pearson correlation: 7.2176e-01	Val MeanMult: 2.9755
# Current learning rate: 6.25e-06
# Epoch: 205	Duration: 72.02s	Train loss: 0.2705	Val loss: 0.3720	Val bias:0.0105	Val Pearson correlation: 7.2176e-01	Val MeanMult: 2.9765
# Current learning rate: 6.25e-06
# Epoch: 206	Duration: 71.38s	Train loss: 0.2701	Val loss: 0.3719	Val bias:0.0081	Val Pearson correlation: 7.2175e-01	Val MeanMult: 2.9756
# Current learning rate: 6.25e-06
# Epoch: 207	Duration: 71.68s	Train loss: 0.2706	Val loss: 0.3719	Val bias:0.0086	Val Pearson correlation: 7.2178e-01	Val MeanMult: 2.9760
# Current learning rate: 6.25e-06
# Epoch: 208	Duration: 70.99s	Train loss: 0.2709	Val loss: 0.3719	Val bias:0.0083	Val Pearson correlation: 7.2180e-01	Val MeanMult: 2.9758
# Current learning rate: 6.25e-06
# Epoch: 209	Duration: 71.32s	Train loss: 0.2710	Val loss: 0.3718	Val bias:0.0084	Val Pearson correlation: 7.2184e-01	Val MeanMult: 2.9752
# Current learning rate: 6.25e-06
# Epoch: 210	Duration: 71.82s	Train loss: 0.2699	Val loss: 0.3718	Val bias:0.0063	Val Pearson correlation: 7.2182e-01	Val MeanMult: 2.9747
# Current learning rate: 6.25e-06
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 70
#      67 with torch.no_grad():
#      68     model.eval()
# ---> 70     val_metrics = compute_eval_metrics(val_dataloader, model)
#      73 hist['train_loss'].append(train_loss/train_steps)
#      74 hist['val_loss'].append(val_metrics['mse'])
#
# Cell In[12], line 49, in compute_eval_metrics(dataloader, model, log)
#      47 for (x,y) in dataloader:
#      48     (x, y) = (x.to(device), y.to(device))
# ---> 49     pred = model(x,task='ft_avgtok')
#      50     mse += MSE(pred, y)
#      51     mean_error += Bias(pred, y)
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# Cell In[10], line 710, in AMBAModel.forward(self, x, task, cluster, mask_patch)
#     707 # finetuning (ft), use the mean of all token (patch) output as clip-level representation.
#     708 # this is default for SSAMBA fine-tuning as during pretraining, supervision signal is given to each token, not the [cls] token
#     709 if task == 'ft_avgtok':
# --> 710     return self.finetuningavgtok(x)
#     711 elif task == 'ft_avgtok_1sec':
#     712     return self.finetuningavgtok_1sec(x)
#
# Cell In[10], line 360, in AMBAModel.finetuningavgtok(self, x)
#     357 if not self.v.if_bidirectional:
#     358     for layer in self.v.layers:
# --> 360         hidden_states, residual = layer(
#     361             hidden_states, residual
#     362         )
#     363 else:
#     364     # get two layers in a single for-loop
#     365     for i in range(len(self.v.layers) // 2):
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/volest/volume-estimation/TTTT/models_mamba.py:110, in Block.forward(self, hidden_states, residual, inference_params)
#     107 else:
#     108     residual = residual + self.drop_path(hidden_states)
# --> 110 hidden_states = self.norm(residual.to(dtype=self.norm.weight.dtype))
#     111 if self.residual_in_fp32:
#     112     residual = residual.to(torch.float32)
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/volest/volume-estimation/TTTT/mamba_ssm/ops/triton/layernorm.py:494, in RMSNorm.forward(self, x, residual, prenorm, residual_in_fp32)
#     493 def forward(self, x, residual=None, prenorm=False, residual_in_fp32=False):
# --> 494     return rms_norm_fn(
#     495         x,
#     496         self.weight,
#     497         self.bias,
#     498         residual=residual,
#     499         eps=self.eps,
#     500         prenorm=prenorm,
#     501         residual_in_fp32=residual_in_fp32,
#     502     )
#
# File ~/volest/volume-estimation/TTTT/mamba_ssm/ops/triton/layernorm.py:478, in rms_norm_fn(x, weight, bias, residual, prenorm, residual_in_fp32, eps)
#     477 def rms_norm_fn(x, weight, bias, residual=None, prenorm=False, residual_in_fp32=False, eps=1e-6):
# --> 478     return LayerNormFn.apply(x, weight, bias, residual, eps, prenorm, residual_in_fp32, True)
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/torch/autograd/function.py:539, in Function.apply(cls, *args, **kwargs)
#     536 if not torch._C._are_functorch_transforms_active():
#     537     # See NOTE: [functorch vjp and autograd interaction]
#     538     args = _functorch.utils.unwrap_dead_wrappers(args)
# --> 539     return super().apply(*args, **kwargs)  # type: ignore[misc]
#     541 if cls.setup_context == _SingleLevelFunction.setup_context:
#     542     raise RuntimeError(
#     543         "In order to use an autograd.Function with functorch transforms "
#     544         "(vmap, grad, jvp, jacrev, ...), it must override the setup_context "
#     545         "staticmethod. For more details, please see "
#     546         "https://pytorch.org/docs/master/notes/extending.func.html"
#     547     )
#
# File ~/volest/volume-estimation/TTTT/mamba_ssm/ops/triton/layernorm.py:411, in LayerNormFn.forward(ctx, x, weight, bias, residual, eps, prenorm, residual_in_fp32, is_rms_norm)
#     405     bias = bias.contiguous()
#     406 residual_dtype = (
#     407     residual.dtype
#     408     if residual is not None
#     409     else (torch.float32 if residual_in_fp32 else None)
#     410 )
# --> 411 y, mean, rstd, residual_out = _layer_norm_fwd(
#     412     x, weight, bias, eps, residual, residual_dtype=residual_dtype, is_rms_norm=is_rms_norm
#     413 )
#     414 ctx.save_for_backward(residual_out, weight, bias, mean, rstd)
#     415 ctx.x_shape_og = x_shape_og
#
# File ~/volest/volume-estimation/TTTT/mamba_ssm/ops/triton/layernorm.py:155, in _layer_norm_fwd(x, weight, bias, eps, residual, out_dtype, residual_dtype, is_rms_norm)
#     153 # heuristics for number of warps
#     154 with torch.cuda.device(x.device.index):
# --> 155     _layer_norm_fwd_1pass_kernel[(M,)](
#     156         x,
#     157         y,
#     158         weight,
#     159         bias,
#     160         residual,
#     161         residual_out,
#     162         mean,
#     163         rstd,
#     164         x.stride(0),
#     165         y.stride(0),
#     166         residual.stride(0) if residual is not None else 0,
#     167         residual_out.stride(0) if residual_out is not None else 0,
#     168         N,
#     169         eps,
#     170         is_rms_norm,
#     171         BLOCK_N,
#     172         residual is not None,
#     173         residual_out is not None,
#     174         bias is not None,
#     175     )
#     176 # residual_out is None if residual is None and residual_dtype == input_dtype
#     177 return y, mean, rstd, residual_out if residual_out is not None else x
#
# File ~/anaconda3/envs/volest_mamba/lib/python3.10/site-packages/triton/runtime/autotuner.py:114, in Autotuner.run(self, *args, **kwargs)
#     112     full_nargs = {**self.nargs, **kwargs, **self.best_config.kwargs}
#     113     config.pre_hook(full_nargs)
# --> 114 ret = self.fn.run(*args, num_warps=config.num_warps, num_stages=config.num_stages, **kwargs, **config.kwargs)
#     115 self.nargs = None
#     116 return ret
#
# File <string>:3, in _layer_norm_fwd_1pass_kernel(X, Y, W, B, RESIDUAL, RESIDUAL_OUT, Mean, Rstd, stride_x_row, stride_y_row, stride_res_row, stride_res_out_row, N, eps, IS_RMS_NORM, BLOCK_N, HAS_RESIDUAL, STORE_RESIDUAL_OUT, HAS_BIAS, grid, num_warps, num_stages, extern_libs, stream, warmup, device, device_type)
#
# File <frozen importlib._bootstrap>:1053, in _handle_fromlist(module, fromlist, import_, recursive)
#
# KeyboardInterrupt:

# %%
with torch.no_grad():
    eval_test = compute_eval_metrics(test_dataloader, model)
    print(eval_test)
# Out:
# {'mse': 0.3700302156204205, 'bias': 0.0004620547191727774, 'pearson_cor': 0.7150143237013774, 'mean_mult': 2.9990112471257873}

# %%
torch.cuda.empty_cache()

# %%
hist.keys()
np.std(hist['val_loss'][15:])
np.arange(100)[-10:]

# %%
random_df = feat_df.sample(20)

random_dataloader = create_dataloader(random_df)
eval_random = compute_eval_metrics(random_dataloader, model)
print(eval_random)

for (x, y) in random_dataloader:
        (x, y) = (x.to(device), y.to(device))
        pred = model(x,task='ft_avgtok')
        print(pred.item())

# %%
class print_Model(Module):
    def __init__(self, seq):
        super(print_Model, self).__init__()
        self.net = seq

    def forward(self, x):
        print("Start\n{}".format(x.size()))
        for layer in self.net:
            x = layer(x)
            print(layer)
            print(x.size())
        return x

# %%
# %load_ext autoreload

# %%
random_df = feat_df.sample(20)

random_dataloader = create_dataloader(random_df, log=False)


load_model = Baseline_Model((input_height, input_width)).to(device)
model_name = 'testrun2_regularization'
load_model.load_state_dict(torch.load(os.path.join(MODELS_DIR,model_name,'model_state.pt'), map_location=torch.device('cpu')))

load_metrics = compute_eval_metrics(test_dataloader, load_model, log=False)
for key in load_metrics.keys():
    print(key, load_metrics[key])

for (x, y) in random_dataloader:
    (x, y) = (x.to(device), y.to(device))
    pred = load_model(x)
    print(pred.item())

# %%
feat_df['vol'].hist()
